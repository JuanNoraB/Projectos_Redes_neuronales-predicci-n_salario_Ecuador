# %% [markdown]
# # 🧠 Privacidad, Anonimización y Generación de Datos Sintéticos en Redes Neuronales
#
# ## Dataset: Información de Empleados del Sector Público Ecuatoriano
#
# **Target**: `RMU_PUESTO` (Remuneración Mensual Unificada del Puesto)

# %% [markdown]
# ---
# ## 📦 1. Selección del Dataset e Identificación de Atributos Sensibles

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

# Configuración de visualización
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette('husl')
pd.set_option('display.max_columns', None)

print('✅ Librerías importadas')
# Out:
# ✅ Librerías importadas

# %%
# Cargar dataset
file_path = 'df_finanzas.csv'
df = pd.read_csv(file_path, sep=';', low_memory=False)

print(f'📊 Dataset cargado: {df.shape[0]:,} filas x {df.shape[1]} columnas\n')
print('Primeras filas:')
df.head()
# Out:
# 📊 Dataset cargado: 99,997 filas x 38 columnas
#
# Primeras filas:
#    ID  EJERCICIO_FISCAL  SECTOR                SECTOR_DESC  ENTIDAD  \
# 0   1              2016     111  ADMINISTRACION DEL ESTADO      320
# 1   2              2016     111  ADMINISTRACION DEL ESTADO      320
# 2   3              2016     111  ADMINISTRACION DEL ESTADO      320
# 3   4              2016     111  ADMINISTRACION DEL ESTADO      140
# 4   5              2016     111  ADMINISTRACION DEL ESTADO      140
#
#                   ENTIDAD_DESC  UNIDAD_EJECUTORA  \
# 0  MINISTERIO DE SALUD PUBLICA              1449
# 1  MINISTERIO DE SALUD PUBLICA              1301
# 2  MINISTERIO DE SALUD PUBLICA              1118
# 3      MINISTERIO DE EDUCACION              6707
# 4      MINISTERIO DE EDUCACION              9005
#
#                                UNIDAD_EJECUTORA_DESC  PARTIDAD_INDIVIDUAL  \
# 0  DIRECCION DISTRITAL 17D07 - PARROQUIAS URBANAS...                    9
# 1  DIRECCION DISTRITAL 12D01 - BABA-BABAHOYO-MONT...                  154
# 2   DIRECCION DISTRITAL 06D05 - GUANO-PENIPE - SALUD                  302
# 3  DIRECCION DISTRITAL 01D02 PARROQUIA URBANA SAN...                  599
# 4  DIRECCION DISTRITAL 17D09 PARROQUIAS RURALES T...                  561
#
#    ENLACE_GRUPO NOMBRE_PROVINCIA NOMBRE_CANTON NUMERO_DOCUMENTO  \
# 0          51.0        PICHINCHA         QUITO        400542163
# 1          51.0         LOS RIOS          BABA       1201962071
# 2          51.0       CHIMBORAZO         GUANO        601392392
# 3          51.0            AZUAY        CUENCA        104346044
# 4          51.0        PICHINCHA         QUITO        602087520
#
#                  APELLIDOS_NOMBRES FECHA_NACIMIENTO     GENERO FECHA_INICIO  \
# 0             ROSERO GOMEZ ROSALBA          1/10/58   FEMENINO       1/1/16
# 1        SUAREZ JURADO HILDA BETTY          17/3/65   FEMENINO       1/1/16
# 2        LEON CARGUA SEGUNDO CELIO          16/8/58  MASCULINO       1/1/16
# 3         ORTIZ VELE MARIA EUGENIA          25/4/84   FEMENINO       1/1/16
# 4  CRUZ INSUASTI ELIZABETH DOLORES          12/9/66   FEMENINO       1/1/16
#
#   FECHA_FIN            NOMBRE_REGIMEN_LABORAL  \
# 0  31/12/16              2-CODIGO DEL TRABAJO
# 1  31/12/16              2-CODIGO DEL TRABAJO
# 2  31/12/16  1-SERVICIO CIVIL PUBLICO (LOSEP)
# 3  31/12/16      3-OTROS REGIMENES ESPECIALES
# 4  31/12/16      3-OTROS REGIMENES ESPECIALES
#
#               NOMBRE_NIVEL_OCUPACIONAL NOMBRE_MODALIDAD_LABORAL  \
# 0        1 CONTRATOS CODIGO DE TRABAJO       CONTRATO COLECTIVO
# 1        1 CONTRATOS CODIGO DE TRABAJO       CONTRATO COLECTIVO
# 2  5 NIVEL OPERATIVO - ESCALAS PROPIAS             NOMBRAMIENTO
# 3   1  EDUCACION PRIMARIA Y SECUNDARIA             NOMBRAMIENTO
# 4   1  EDUCACION PRIMARIA Y SECUNDARIA             NOMBRAMIENTO
#
#   DESCRIPCION_ESCALA_OCUPACIONAL  \
# 0                        NIVEL 7
# 1                        NIVEL 7
# 2            INSPECTOR SANITARIO
# 3            DOCENTE CATEGORIA F
# 4            DOCENTE CATEGORIA E
#
#                           NOMBRE_DENOMINACION_PUESTO RMU_PUESTO  \
# 0  AUXILIAR ADMINISTRATIVO DE SALUD DEL SECTOR SALUD     596.92
# 1                             AUXILIAR DE ENFERMERIA        805
# 2                                INSPECTOR SANITARIO        735
# 3                                DOCENTE CATEGORIA F        901
# 4                                DOCENTE CATEGORIA E        986
#
#   ACUMULA_DEC_TERCERO ACUMULA_DEC_CUARTO COMISION_SERVICIO_TIPO  \
# 0                   S                  S                    NaN
# 1                   S                  S                    NaN
# 2                   S                  S                    NaN
# 3                   N                  N                    NaN
# 4                   S                  S                    NaN
#
#   NOMBRE_ESTADO_PUESTO NOMBRE_ESTADO_SERVIDOR  \
# 0              OCUPADO                 ACTIVO
# 1              OCUPADO                 ACTIVO
# 2              OCUPADO                 ACTIVO
# 3              OCUPADO                 ACTIVO
# 4              OCUPADO                 ACTIVO
#
#         NOMBRE_UNIDAD_ORGANIZACIONAL  \
# 0         ATENCION INTEGRAL EN SALUD
# 1         ATENCION INTEGRAL EN SALUD
# 2          VIGILANCIA EPIDEMIOLOGICA
# 3  DOCENTES EDUCACION GENERAL BASICA
# 4                  RICARDO RODRIGUEZ
#
#                          ESTRUCTURA_ORGANICA RUC_PATRONAL Unnamed: 32  \
# 0  PROCESO DESCONCENTRADO AGREGADOR DE VALOR  1,76804E+12         NaN
# 1  PROCESO DESCONCENTRADO AGREGADOR DE VALOR  1,26001E+12         NaN
# 2                 PROCESO AGREGADOR DE VALOR  6,60806E+11         NaN
# 3                 PROCESO AGREGADOR DE VALOR   1,6006E+11         NaN
# 4                 PROCESO AGREGADOR DE VALOR  1,76817E+12         NaN
#
#   Unnamed: 33 Unnamed: 34 Unnamed: 35 Unnamed: 36 Unnamed: 37
# 0         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN

# %%
# Definición de columnas por categoría de sensibilidad

cols_eliminar = [
    "ID", "EJERCICIO_FISCAL", "SECTOR", "ENTIDAD", "ENTIDAD_DESC",
    "UNIDAD_EJECUTORA", "UNIDAD_EJECUTORA_DESC", "PARTIDAD_INDIVIDUAL",
    "ENLACE_GRUPO", "APELLIDOS_NOMBRES", "FECHA_FIN", "NOMBRE_MODALIDAD_LABORAL",
    "DESCRIPCION_ESCALA_OCUPACIONAL", "NOMBRE_ESTADO_SERVIDOR", "ESTRUCTURA_ORGANICA",
    "RUC_PATRONAL"
]

cols_anonimizar = [
    "NOMBRE_PROVINCIA", "NOMBRE_CANTON", "NUMERO_DOCUMENTO",
    "FECHA_NACIMIENTO", "FECHA_INICIO", "GENERO",
    "NOMBRE_UNIDAD_ORGANIZACIONAL"
]

cols_conservar = [
    "SECTOR_DESC", "NOMBRE_REGIMEN_LABORAL", "NOMBRE_NIVEL_OCUPACIONAL",
    "NOMBRE_DENOMINACION_PUESTO", "RMU_PUESTO", "ACUMULA_DEC_TERCERO",
    "ACUMULA_DEC_CUARTO", "NOMBRE_ESTADO_PUESTO"
]

print('🔒 ATRIBUTOS SENSIBLES IDENTIFICADOS:\n')
print(f'✖️  Eliminar ({len(cols_eliminar)}): Identificadores directos y datos administrativos innecesarios')
print(f'🔐 Anonimizar ({len(cols_anonimizar)}): Datos cuasi-identificadores (pueden reidentificar combinados)')
print(f'✅ Conservar ({len(cols_conservar)}): Datos no sensibles útiles para el modelo')
print('\n🎯 TARGET: RMU_PUESTO (Remuneración Mensual Unificada)')
# Out:
# 🔒 ATRIBUTOS SENSIBLES IDENTIFICADOS:
#
# ✖️  Eliminar (16): Identificadores directos y datos administrativos innecesarios
# 🔐 Anonimizar (7): Datos cuasi-identificadores (pueden reidentificar combinados)
# ✅ Conservar (8): Datos no sensibles útiles para el modelo
#
# 🎯 TARGET: RMU_PUESTO (Remuneración Mensual Unificada)

# %% [markdown]
# **Riesgos de Privacidad Identificados:**
# - **Identificadores directos**: `APELLIDOS_NOMBRES`, `NUMERO_DOCUMENTO` → pueden identificar individuos
# - **Cuasi-identificadores**: Combinación de `FECHA_NACIMIENTO` + `GENERO` + `NOMBRE_PROVINCIA` + `NOMBRE_CANTON` puede reidentificar personas (Netflix Prize attack)
# - **Datos sensibles**: Ubicación geográfica precisa y fechas exactas

# %% [markdown]
# ---
# ## 📊 2. Análisis Exploratorio (sin revelar datos individuales)

# %%
# Limpieza básica previa
valores_validos = ["S", "N"]
df = df[df["ACUMULA_DEC_CUARTO"].isin(valores_validos)].copy()
df = df[df["ACUMULA_DEC_TERCERO"].isin(valores_validos)].copy()

# Eliminar provincias erróneas (países extranjeros)
valores_a_eliminar = [
    "ESTADO ESTADOS UNIDOS", "ESTADO COLOMBIA", "ESTADO ESPAÑA",
    "ESTADO CANADA", "ESTADO ITALIA", "ESTADO ARGENTINA",
    "ESTADO CHINA", "ESTADO PERU", "ESTADO CHILE", "REGIONAL"
]
df = df[~df['NOMBRE_PROVINCIA'].isin(valores_a_eliminar)].copy()

# Normalizar género
df['GENERO'] = df['GENERO'].replace({'MUJER': 'FEMENINO', 'HOMBRE': 'MASCULINO'})

# Convertir RMU_PUESTO a numérico
df['RMU_PUESTO'] = df['RMU_PUESTO'].astype(str).str.replace(',', '.').astype(float)

print(f'✅ Dataset limpio: {df.shape[0]:,} filas x {df.shape[1]} columnas')
print(f'🗑️  Se eliminaron {99997 - df.shape[0]:,} filas con datos inconsistentes')
# Out:
# ✅ Dataset limpio: 99,629 filas x 38 columnas
# 🗑️  Se eliminaron 368 filas con datos inconsistentes

# %%
# Análisis del target (RMU_PUESTO)
print('📈 ANÁLISIS DEL TARGET: RMU_PUESTO\n')
print(df['RMU_PUESTO'].describe())

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Histograma
axes[0].hist(df['RMU_PUESTO'], bins=50, edgecolor='black', alpha=0.7)
axes[0].set_title('Distribución de Remuneraciones', fontsize=12, fontweight='bold')
axes[0].set_xlabel('RMU (USD)')
axes[0].set_ylabel('Frecuencia')
axes[0].axvline(df['RMU_PUESTO'].median(), color='red', linestyle='--', label=f'Mediana: ${df["RMU_PUESTO"].median():.2f}')
axes[0].legend()

# Boxplot
axes[1].boxplot(df['RMU_PUESTO'], vert=True)
axes[1].set_title('Boxplot de Remuneraciones', fontsize=12, fontweight='bold')
axes[1].set_ylabel('RMU (USD)')

plt.tight_layout()
plt.show()

print(f'\n💡 La distribución está sesgada hacia salarios bajos, con algunos valores atípicos altos')
# Out:
# 📈 ANÁLISIS DEL TARGET: RMU_PUESTO
#
# count    99629.000000
# mean       967.907471
# std        524.457903
# min          1.000000
# 25%        735.000000
# 50%        817.000000
# 75%       1212.000000
# max      16313.400000
# Name: RMU_PUESTO, dtype: float64
# 💡 La distribución está sesgada hacia salarios bajos, con algunos valores atípicos altos

# %%
# Creación de clases para el target (clasificación)
# PROBLEMA DETECTADO: 4 clases con cuartiles crean solapamiento
# Medio-Bajo ($735-$817) y Medio-Alto ($818-$1212) son muy difíciles de separar

# ESTRATEGIA 1: Usar percentiles 33-66 (3 CLASES) - Mejor separación
percentiles = df['RMU_PUESTO'].quantile([0.33, 0.66]).values

def clasificar_sueldo_3clases(rmu):
    if rmu <= percentiles[0]:
        return 'Bajo'
    elif rmu <= percentiles[1]:
        return 'Medio'
    else:
        return 'Alto'

df['CATEGORIA_SUELDO'] = df['RMU_PUESTO'].apply(clasificar_sueldo_3clases)

print('📊 CATEGORIZACIÓN DEL SUELDO (Target para clasificación):\n')
print('🔄 USANDO 3 CLASES (en vez de 4) para mejor separación:\n')
print(f'Bajo:   ≤ ${percentiles[0]:.2f}')
print(f'Medio:  ${percentiles[0]:.2f} - ${percentiles[1]:.2f}')
print(f'Alto:   > ${percentiles[1]:.2f}')
print(f'\nDistribución de clases:')
print(df['CATEGORIA_SUELDO'].value_counts().sort_index())

# Visualización
df['CATEGORIA_SUELDO'].value_counts().plot(kind='bar', color='steelblue', edgecolor='black')
plt.title('Distribución de Categorías de Sueldo (3 Clases)', fontweight='bold')
plt.xlabel('Categoría')
plt.ylabel('Frecuencia')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

print('\n💡 Ventaja: Reducir confusión entre clases medias que estaban muy cerca')
# Out:
# 📊 CATEGORIZACIÓN DEL SUELDO (Target para clasificación):
#
# 🔄 USANDO 3 CLASES (en vez de 4) para mejor separación:
#
# Bajo:   ≤ $817.00
# Medio:  $817.00 - $986.00
# Alto:   > $986.00
#
# Distribución de clases:
# CATEGORIA_SUELDO
# Alto     30279
# Bajo     54853
# Medio    14497
# Name: count, dtype: int64
# 💡 Ventaja: Reducir confusión entre clases medias que estaban muy cerca

# %%
# Análisis de correlación con atributos sensibles (agregado)
print('🔍 ANÁLISIS DE RIESGOS DE REIDENTIFICACIÓN:\n')

# Conteo de combinaciones únicas de cuasi-identificadores
combinaciones = df.groupby(['NOMBRE_PROVINCIA', 'GENERO']).size().reset_index(name='count')
unicos = combinaciones[combinaciones['count'] == 1]

print(f'⚠️  Registros únicos por Provincia+Género: {len(unicos)} ({len(unicos)/len(df)*100:.2f}%)')
print(f'   → Estos registros son más vulnerables a reidentificación\n')

# Distribución de género
print('Distribución por género:')
print(df['GENERO'].value_counts())
print(f'\n📍 Total de provincias: {df["NOMBRE_PROVINCIA"].nunique()}')
print(f'📍 Total de cantones: {df["NOMBRE_CANTON"].nunique()}')
# Out:
# 🔍 ANÁLISIS DE RIESGOS DE REIDENTIFICACIÓN:
#
# ⚠️  Registros únicos por Provincia+Género: 0 (0.00%)
#    → Estos registros son más vulnerables a reidentificación
#
# Distribución por género:
# GENERO
# FEMENINO     61857
# MASCULINO    37748
# Name: count, dtype: int64
#
# 📍 Total de provincias: 24
# 📍 Total de cantones: 208

# %% [markdown]
# ---
# ## 🔐 3. Anonimización del Dataset

# %%
# Crear copia para anonimización
df_anonimizado = df.copy()

print('🔐 APLICANDO TÉCNICAS DE ANONIMIZACIÓN:\n')

# 1. SUPRESIÓN: Eliminar columnas con identificadores directos
cols_a_eliminar = [col for col in cols_eliminar if col in df_anonimizado.columns]
df_anonimizado.drop(columns=cols_a_eliminar, inplace=True)
print(f'✅ 1. SUPRESIÓN: {len(cols_a_eliminar)} columnas eliminadas')

# 2. GENERALIZACIÓN: Fecha de nacimiento → Edad → Rango etario
df_anonimizado['FECHA_NACIMIENTO'] = pd.to_datetime(df_anonimizado['FECHA_NACIMIENTO'], errors='coerce')
df_anonimizado['EDAD'] = (pd.Timestamp('2016-01-01') - df_anonimizado['FECHA_NACIMIENTO']).dt.days // 365

def edad_a_rango(edad):
    if pd.isna(edad):
        return 'Desconocido'
    elif edad < 30:
        return '18-29'
    elif edad < 40:
        return '30-39'
    elif edad < 50:
        return '40-49'
    elif edad < 60:
        return '50-59'
    else:
        return '60+'

df_anonimizado['RANGO_EDAD'] = df_anonimizado['EDAD'].apply(edad_a_rango)
df_anonimizado.drop(columns=['FECHA_NACIMIENTO', 'EDAD'], inplace=True)
print('✅ 2. GENERALIZACIÓN: Fecha nacimiento → Rango etario (5 grupos)')

# 3. GENERALIZACIÓN: Fecha de inicio → Año de inicio
df_anonimizado['FECHA_INICIO'] = pd.to_datetime(df_anonimizado['FECHA_INICIO'], errors='coerce')
df_anonimizado['ANIO_INICIO'] = df_anonimizado['FECHA_INICIO'].dt.year
df_anonimizado.drop(columns=['FECHA_INICIO'], inplace=True)
print('✅ 3. GENERALIZACIÓN: Fecha inicio → Año de inicio')

# 4. SUPRESIÓN: Eliminar documento y cantón (muy específicos)
df_anonimizado.drop(columns=['NUMERO_DOCUMENTO', 'NOMBRE_CANTON'], inplace=True, errors='ignore')
print('✅ 4. SUPRESIÓN: Número documento y cantón eliminados')

# 5. CODIFICACIÓN: Convertir género a binario
df_anonimizado['GENERO_CODIGO'] = (df_anonimizado['GENERO'] == 'MASCULINO').astype(int)
df_anonimizado.drop(columns=['GENERO'], inplace=True)
print('✅ 5. CODIFICACIÓN: Género → Binario (0/1)')

# 6. GENERALIZACIÓN: Unidad organizacional → Hash (k-anonimato)
df_anonimizado['UNIDAD_ORG_HASH'] = df_anonimizado['NOMBRE_UNIDAD_ORGANIZACIONAL'].astype(str).apply(lambda x: hash(x) % 100)
df_anonimizado.drop(columns=['NOMBRE_UNIDAD_ORGANIZACIONAL'], inplace=True)
print('✅ 6. PERTURBACIÓN: Unidad organizacional → Hash mod 100')

print(f'\n📊 Dataset anonimizado: {df_anonimizado.shape[0]:,} filas x {df_anonimizado.shape[1]} columnas')
print(f'🔒 Reducción de {df.shape[1]} → {df_anonimizado.shape[1]} columnas')
# Out:
# 🔐 APLICANDO TÉCNICAS DE ANONIMIZACIÓN:
#
# ✅ 1. SUPRESIÓN: 16 columnas eliminadas
# C:\Users\juan_\AppData\Local\Temp\ipykernel_35660\3417154219.py:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_anonimizado['FECHA_NACIMIENTO'] = pd.to_datetime(df_anonimizado['FECHA_NACIMIENTO'], errors='coerce')
# ✅ 2. GENERALIZACIÓN: Fecha nacimiento → Rango etario (5 grupos)
# ✅ 3. GENERALIZACIÓN: Fecha inicio → Año de inicio
# ✅ 4. SUPRESIÓN: Número documento y cantón eliminados
# ✅ 5. CODIFICACIÓN: Género → Binario (0/1)
# ✅ 6. PERTURBACIÓN: Unidad organizacional → Hash mod 100
#
# 📊 Dataset anonimizado: 99,629 filas x 21 columnas
# 🔒 Reducción de 39 → 21 columnas
# C:\Users\juan_\AppData\Local\Temp\ipykernel_35660\3417154219.py:34: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_anonimizado['FECHA_INICIO'] = pd.to_datetime(df_anonimizado['FECHA_INICIO'], errors='coerce')

# %%
# Comparación visual: Original vs Anonimizado
print('📋 COLUMNAS DEL DATASET ANONIMIZADO:\n')
print(df_anonimizado.columns.tolist())
print('\nPrimeras filas del dataset anonimizado:')
df_anonimizado.head(10)
# Out:
# 📋 COLUMNAS DEL DATASET ANONIMIZADO:
#
# ['SECTOR_DESC', 'NOMBRE_PROVINCIA', 'NOMBRE_REGIMEN_LABORAL', 'NOMBRE_NIVEL_OCUPACIONAL', 'NOMBRE_DENOMINACION_PUESTO', 'RMU_PUESTO', 'ACUMULA_DEC_TERCERO', 'ACUMULA_DEC_CUARTO', 'COMISION_SERVICIO_TIPO', 'NOMBRE_ESTADO_PUESTO', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'CATEGORIA_SUELDO', 'RANGO_EDAD', 'ANIO_INICIO', 'GENERO_CODIGO', 'UNIDAD_ORG_HASH']
#
# Primeras filas del dataset anonimizado:
#                  SECTOR_DESC NOMBRE_PROVINCIA  \
# 0  ADMINISTRACION DEL ESTADO        PICHINCHA
# 1  ADMINISTRACION DEL ESTADO         LOS RIOS
# 2  ADMINISTRACION DEL ESTADO       CHIMBORAZO
# 3  ADMINISTRACION DEL ESTADO            AZUAY
# 4  ADMINISTRACION DEL ESTADO        PICHINCHA
# 5  ADMINISTRACION DEL ESTADO           CARCHI
# 6  ADMINISTRACION DEL ESTADO           MANABI
# 7  ADMINISTRACION DEL ESTADO           GUAYAS
# 8  ADMINISTRACION DEL ESTADO             LOJA
# 9  ADMINISTRACION DEL ESTADO        PICHINCHA
#
#              NOMBRE_REGIMEN_LABORAL             NOMBRE_NIVEL_OCUPACIONAL  \
# 0              2-CODIGO DEL TRABAJO        1 CONTRATOS CODIGO DE TRABAJO
# 1              2-CODIGO DEL TRABAJO        1 CONTRATOS CODIGO DE TRABAJO
# 2  1-SERVICIO CIVIL PUBLICO (LOSEP)  5 NIVEL OPERATIVO - ESCALAS PROPIAS
# 3      3-OTROS REGIMENES ESPECIALES   1  EDUCACION PRIMARIA Y SECUNDARIA
# 4      3-OTROS REGIMENES ESPECIALES   1  EDUCACION PRIMARIA Y SECUNDARIA
# 5      3-OTROS REGIMENES ESPECIALES   1  EDUCACION PRIMARIA Y SECUNDARIA
# 6      3-OTROS REGIMENES ESPECIALES   1  EDUCACION PRIMARIA Y SECUNDARIA
# 7      3-OTROS REGIMENES ESPECIALES   1  EDUCACION PRIMARIA Y SECUNDARIA
# 8  1-SERVICIO CIVIL PUBLICO (LOSEP)                   2  NIVEL OPERATIVO
# 9  1-SERVICIO CIVIL PUBLICO (LOSEP)                   2  NIVEL OPERATIVO
#
#                           NOMBRE_DENOMINACION_PUESTO  RMU_PUESTO  \
# 0  AUXILIAR ADMINISTRATIVO DE SALUD DEL SECTOR SALUD      596.92
# 1                             AUXILIAR DE ENFERMERIA      805.00
# 2                                INSPECTOR SANITARIO      735.00
# 3                                DOCENTE CATEGORIA F      901.00
# 4                                DOCENTE CATEGORIA E      986.00
# 5                                DOCENTE CATEGORIA G      817.00
# 6                                DOCENTE CATEGORIA C     1212.00
# 7                                DOCENTE CATEGORIA G      817.00
# 8                                           ANALISTA      901.00
# 9                         CONTROLADOR DE AERODROMO 1      986.00
#
#   ACUMULA_DEC_TERCERO ACUMULA_DEC_CUARTO COMISION_SERVICIO_TIPO  \
# 0                   S                  S                    NaN
# 1                   S                  S                    NaN
# 2                   S                  S                    NaN
# 3                   N                  N                    NaN
# 4                   S                  S                    NaN
# 5                   N                  N                    NaN
# 6                   S                  S                    NaN
# 7                   N                  N                    NaN
# 8                   S                  S                    NaN
# 9                   S                  S                    NaN
#
#   NOMBRE_ESTADO_PUESTO Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35  \
# 0              OCUPADO         NaN         NaN         NaN         NaN
# 1              OCUPADO         NaN         NaN         NaN         NaN
# 2              OCUPADO         NaN         NaN         NaN         NaN
# 3              OCUPADO         NaN         NaN         NaN         NaN
# 4              OCUPADO         NaN         NaN         NaN         NaN
# 5              OCUPADO         NaN         NaN         NaN         NaN
# 6              OCUPADO         NaN         NaN         NaN         NaN
# 7              OCUPADO         NaN         NaN         NaN         NaN
# 8              OCUPADO         NaN         NaN         NaN         NaN
# 9              OCUPADO         NaN         NaN         NaN         NaN
#
#   Unnamed: 36 Unnamed: 37 CATEGORIA_SUELDO RANGO_EDAD  ANIO_INICIO  \
# 0         NaN         NaN             Bajo      18-29         2016
# 1         NaN         NaN             Bajo      18-29         2016
# 2         NaN         NaN             Bajo      18-29         2016
# 3         NaN         NaN            Medio      30-39         2016
# 4         NaN         NaN            Medio      18-29         2016
# 5         NaN         NaN             Bajo      18-29         2016
# 6         NaN         NaN             Alto      18-29         2016
# 7         NaN         NaN             Bajo      30-39         2016
# 8         NaN         NaN            Medio      18-29         2016
# 9         NaN         NaN            Medio      18-29         2016
#
#    GENERO_CODIGO  UNIDAD_ORG_HASH
# 0              0               99
# 1              0               99
# 2              1                0
# 3              0               59
# 4              0               69
# 5              0               34
# 6              1               21
# 7              0               23
# 8              1               71
# 9              0                1

# %%
# Verificar que el target se preservó correctamente
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Original
df['CATEGORIA_SUELDO'].value_counts().plot(kind='bar', ax=axes[0], color='coral', edgecolor='black')
axes[0].set_title('Target Original', fontweight='bold')
axes[0].set_xlabel('Categoría')
axes[0].set_ylabel('Frecuencia')
axes[0].tick_params(axis='x', rotation=45)

# Anonimizado
df_anonimizado['CATEGORIA_SUELDO'].value_counts().plot(kind='bar', ax=axes[1], color='steelblue', edgecolor='black')
axes[1].set_title('Target Anonimizado', fontweight='bold')
axes[1].set_xlabel('Categoría')
axes[1].set_ylabel('Frecuencia')
axes[1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

print('✅ El target se preservó correctamente tras la anonimización')
# Out:
# ✅ El target se preservó correctamente tras la anonimización

# %% [markdown]
# ### 📝 Resumen de Técnicas de Anonimización Aplicadas:
#
# | Técnica | Aplicación | Protección |
# |---------|-----------|------------|
# | **Supresión** | Eliminación de identificadores directos (nombres, ID, documentos) | Alta |
# | **Generalización** | Fecha → Rango etario (5 grupos), Fecha → Año | Media-Alta |
# | **Codificación** | Género → Binario (0/1) | Media |
# | **Perturbación** | Unidad organizacional → Hash | Media |
#
# **🎯 Resultado**: Dataset con riesgo de reidentificación significativamente reducido, preservando utilidad para el modelo.

# %% [markdown]
# ---
# ## 💾 Guardado de Datasets

# %%
# Guardar datasets para uso posterior
df_anonimizado.to_csv('df_anonimizado.csv', index=False)
print('✅ Dataset anonimizado guardado')

# Preparar dataset original limpio
df_original_limpio = df.copy()

# Seleccionar columnas relevantes
cols_finales = list(set(cols_conservar + cols_anonimizar + ['CATEGORIA_SUELDO']))
df_original_limpio = df_original_limpio[[col for col in cols_finales if col in df_original_limpio.columns]].copy()

# Transformaciones
df_original_limpio = df_original_limpio.dropna(subset=['GENERO'])

if 'NUMERO_DOCUMENTO' in df_original_limpio.columns:
    df_original_limpio = df_original_limpio.drop(columns=['NUMERO_DOCUMENTO'])

if 'FECHA_NACIMIENTO' in df_original_limpio.columns:
    df_original_limpio['FECHA_NACIMIENTO'] = pd.to_datetime(df_original_limpio['FECHA_NACIMIENTO'], format='%d/%m/%y', errors='coerce')
    df_original_limpio['FECHA_NACIMIENTO'] = df_original_limpio['FECHA_NACIMIENTO'].apply(
        lambda x: x - pd.DateOffset(years=100) if pd.notna(x) and x.year > 2016 else x
    )
    df_original_limpio['EDAD'] = (pd.Timestamp('2016-01-01') - df_original_limpio['FECHA_NACIMIENTO']).dt.days // 365
    df_original_limpio = df_original_limpio.drop(columns=['FECHA_NACIMIENTO'])

if 'FECHA_INICIO' in df_original_limpio.columns:
    df_original_limpio['FECHA_INICIO'] = pd.to_datetime(df_original_limpio['FECHA_INICIO'], format='%d/%m/%y', errors='coerce')
    df_original_limpio['ANTIGUEDAD_DIAS'] = (pd.Timestamp('2016-01-01') - df_original_limpio['FECHA_INICIO']).dt.days
    df_original_limpio['ANTIGUEDAD_DIAS'] = df_original_limpio['ANTIGUEDAD_DIAS'].clip(lower=0)
    df_original_limpio = df_original_limpio.drop(columns=['FECHA_INICIO'])

# REGENERAR CATEGORIA_SUELDO CON 3 CLASES AQUÍ
percentiles_save = df_original_limpio['RMU_PUESTO'].quantile([0.33, 0.66]).values
df_original_limpio['CATEGORIA_SUELDO'] = df_original_limpio['RMU_PUESTO'].apply(
    lambda x: 'Bajo' if x <= percentiles_save[0] else ('Medio' if x <= percentiles_save[1] else 'Alto')
)

df_original_limpio.to_csv('df_original_limpio.csv', index=False)
print('✅ Dataset original limpio guardado con 3 clases')
print(f'   Distribución: {df_original_limpio["CATEGORIA_SUELDO"].value_counts().to_dict()}')
# Out:
# ✅ Dataset anonimizado guardado
# ✅ Dataset original limpio guardado con 3 clases
#    Distribución: {'Bajo': 54835, 'Alto': 30273, 'Medio': 14497}

# %% [markdown]
# ---
# # 🤖 4. Entrenamiento de Red Neuronal
#
# ## Comparación: Dataset Original vs Dataset Anonimizado

# %%
# Importar librerías para Red Neuronal
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

print(f'✅ TensorFlow version: {tf.__version__}')
# Out:
# ✅ TensorFlow version: 2.20.0

# %% [markdown]
# ### 📊 Preparación de Datos - Dataset Original

# %%
# Preparar dataset original
df_original = df_original_limpio.copy()

print('Dataset Original:')
print(f'  Filas: {df_original.shape[0]:,}')
print(f'  Columnas: {df_original.shape[1]}')
print(f'  Clases: {df_original["CATEGORIA_SUELDO"].unique()}')
print(f'  Distribución: {df_original["CATEGORIA_SUELDO"].value_counts().to_dict()}')

# Separar features y target
X_original = df_original.drop(['CATEGORIA_SUELDO', 'RMU_PUESTO'], axis=1)
y_original = df_original['CATEGORIA_SUELDO']

# Identificar columnas numéricas y categóricas
numeric_cols = X_original.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_cols = X_original.select_dtypes(include=['object']).columns.tolist()

print(f'\nFeatures:')
print(f'  Numéricas: {len(numeric_cols)}')
print(f'  Categóricas: {len(categorical_cols)}')
# Out:
# Dataset Original:
#   Filas: 99,605
#   Columnas: 15
#   Clases: ['Bajo' 'Medio' 'Alto']
#   Distribución: {'Bajo': 54835, 'Alto': 30273, 'Medio': 14497}
#
# Features:
#   Numéricas: 2
#   Categóricas: 11

# %%
# Encoding de variables categóricas
X_original_encoded = X_original.copy()

label_encoders_original = {}
for col in categorical_cols:
    le = LabelEncoder()
    X_original_encoded[col] = le.fit_transform(X_original_encoded[col].astype(str))
    label_encoders_original[col] = le

# Encoding del target
le_target = LabelEncoder()
y_original_encoded = le_target.fit_transform(y_original)

print(f'Target: {len(le_target.classes_)} clases → {le_target.classes_}')
print(f'Labels: {np.unique(y_original_encoded)}')

# División train/test
X_train_orig, X_test_orig, y_train_orig, y_test_orig = train_test_split(
    X_original_encoded, y_original_encoded, test_size=0.2, random_state=42, stratify=y_original_encoded
)

# Normalización
scaler_original = StandardScaler()
X_train_orig_scaled = scaler_original.fit_transform(X_train_orig)
X_test_orig_scaled = scaler_original.transform(X_test_orig)

print(f'Train: {X_train_orig_scaled.shape[0]:,} | Test: {X_test_orig_scaled.shape[0]:,}')
# Out:
# Target: 3 clases → ['Alto' 'Bajo' 'Medio']
# Labels: [0 1 2]
# Train: 79,684 | Test: 19,921

# %%
def crear_modelo(input_dim, num_clases=3):
    model = models.Sequential([
        layers.Input(shape=(input_dim,)),
        layers.Dense(256, activation='relu', kernel_initializer='he_normal'),
        layers.BatchNormalization(),
        layers.Dropout(0.4),
        layers.Dense(128, activation='relu', kernel_initializer='he_normal'),
        layers.BatchNormalization(),
        layers.Dropout(0.3),
        layers.Dense(128, activation='relu', kernel_initializer='he_normal'),
        layers.BatchNormalization(),
        layers.Dropout(0.3),
        layers.Dense(64, activation='relu', kernel_initializer='he_normal'),
        layers.BatchNormalization(),
        layers.Dropout(0.2),
        layers.Dense(32, activation='relu', kernel_initializer='he_normal'),
        layers.Dropout(0.2),
        layers.Dense(num_clases, activation='softmax')
    ])
    
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=0.001),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

input_dim = X_train_orig_scaled.shape[1]
modelo_original = crear_modelo(input_dim, num_clases=3)

print('Modelo creado:')
modelo_original.summary()
# Out:
# Modelo creado:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 256)            │         3,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 3)              │            99 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 65,731 (256.76 KB)
#  Trainable params: 64,579 (252.26 KB)
#  Non-trainable params: 1,152 (4.50 KB)

# %%
# Callbacks MEJORADOS para optimizar el entrenamiento
early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=20,  # Más paciencia para arquitectura compleja
    restore_best_weights=True,
    verbose=1
)

reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=7,  # Reducir LR más rápido
    min_lr=1e-7,
    verbose=1
)

# Entrenar modelo
print('🚀 ENTRENANDO RED NEURONAL MEJORADA CON DATASET ORIGINAL...\\n')
print('📊 Configuración:')
print(f'   - Arquitectura: 5 capas ocultas (256→128→128→64→32)')
print(f'   - Clases: 3 (Bajo, Medio, Alto)')
print(f'   - Épocas máximas: 150')
print(f'   - Batch size: 32')
print(f'   - Early stopping: patience=20')
print('\\n')

history_original = modelo_original.fit(
    X_train_orig_scaled, y_train_orig,
    validation_split=0.2,
    epochs=150,  # Más épocas para red más compleja
    batch_size=32,
    callbacks=[early_stopping, reduce_lr],
    verbose=1
)

print('\\n✅ Entrenamiento completado')
print(f'📈 Épocas entrenadas: {len(history_original.history["loss"])}')
# Out:
# 🚀 ENTRENANDO RED NEURONAL MEJORADA CON DATASET ORIGINAL...\n
# 📊 Configuración:
#    - Arquitectura: 5 capas ocultas (256→128→128→64→32)
#    - Clases: 3 (Bajo, Medio, Alto)
#    - Épocas máximas: 150
#    - Batch size: 32
#    - Early stopping: patience=20
# \n
# Epoch 1/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.6787 - loss: 0.7608 - val_accuracy: 0.7389 - val_loss: 0.5941 - learning_rate: 0.0010
# Epoch 2/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7227 - loss: 0.6410 - val_accuracy: 0.7523 - val_loss: 0.5843 - learning_rate: 0.0010
# Epoch 3/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - accuracy: 0.7340 - loss: 0.6167 - val_accuracy: 0.7549 - val_loss: 0.5624 - learning_rate: 0.0010
# Epoch 4/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7397 - loss: 0.6009 - val_accuracy: 0.7559 - val_loss: 0.5539 - learning_rate: 0.0010
# Epoch 5/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7415 - loss: 0.5917 - val_accuracy: 0.7551 - val_loss: 0.5462 - learning_rate: 0.0010
# Epoch 6/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.7456 - loss: 0.5836 - val_accuracy: 0.7607 - val_loss: 0.5376 - learning_rate: 0.0010
# Epoch 7/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.7478 - loss: 0.5785 - val_accuracy: 0.7643 - val_loss: 0.5297 - learning_rate: 0.0010
# Epoch 8/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7502 - loss: 0.5706 - val_accuracy: 0.7639 - val_loss: 0.5214 - learning_rate: 0.0010
# Epoch 9/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7552 - loss: 0.5601 - val_accuracy: 0.7704 - val_loss: 0.5144 - learning_rate: 0.0010
# Epoch 10/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7611 - loss: 0.5484 - val_accuracy: 0.7793 - val_loss: 0.4980 - learning_rate: 0.0010
# Epoch 11/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.7671 - loss: 0.5358 - val_accuracy: 0.7818 - val_loss: 0.4868 - learning_rate: 0.0010
# Epoch 12/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7723 - loss: 0.5244 - val_accuracy: 0.7835 - val_loss: 0.4933 - learning_rate: 0.0010
# Epoch 13/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7765 - loss: 0.5163 - val_accuracy: 0.8034 - val_loss: 0.4549 - learning_rate: 0.0010
# Epoch 14/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7814 - loss: 0.5094 - val_accuracy: 0.7425 - val_loss: 0.5066 - learning_rate: 0.0010
# Epoch 15/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7636 - loss: 0.5425 - val_accuracy: 0.7853 - val_loss: 0.4781 - learning_rate: 0.0010
# Epoch 16/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7844 - loss: 0.5038 - val_accuracy: 0.8226 - val_loss: 0.4431 - learning_rate: 0.0010
# Epoch 17/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7936 - loss: 0.4808 - val_accuracy: 0.8339 - val_loss: 0.4386 - learning_rate: 0.0010
# Epoch 18/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8019 - loss: 0.4668 - val_accuracy: 0.8379 - val_loss: 0.4228 - learning_rate: 0.0010
# Epoch 19/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8086 - loss: 0.4578 - val_accuracy: 0.8199 - val_loss: 0.4132 - learning_rate: 0.0010
# Epoch 20/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.8132 - loss: 0.4470 - val_accuracy: 0.8479 - val_loss: 0.3835 - learning_rate: 0.0010
# Epoch 21/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8180 - loss: 0.4426 - val_accuracy: 0.8104 - val_loss: 0.4149 - learning_rate: 0.0010
# Epoch 22/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8190 - loss: 0.4367 - val_accuracy: 0.8766 - val_loss: 0.3894 - learning_rate: 0.0010
# Epoch 23/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8212 - loss: 0.4346 - val_accuracy: 0.8252 - val_loss: 0.4160 - learning_rate: 0.0010
# Epoch 24/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8212 - loss: 0.4321 - val_accuracy: 0.7309 - val_loss: 0.5487 - learning_rate: 0.0010
# Epoch 25/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8254 - loss: 0.4281 - val_accuracy: 0.7475 - val_loss: 0.5048 - learning_rate: 0.0010
# Epoch 26/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8290 - loss: 0.4172 - val_accuracy: 0.7335 - val_loss: 0.5305 - learning_rate: 0.0010
# Epoch 27/150
# 1989/1993 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8264 - loss: 0.4206
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8279 - loss: 0.4174 - val_accuracy: 0.7489 - val_loss: 0.5081 - learning_rate: 0.0010
# Epoch 28/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8460 - loss: 0.3835 - val_accuracy: 0.8201 - val_loss: 0.4068 - learning_rate: 5.0000e-04
# Epoch 29/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8498 - loss: 0.3759 - val_accuracy: 0.7823 - val_loss: 0.4495 - learning_rate: 5.0000e-04
# Epoch 30/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8540 - loss: 0.3663 - val_accuracy: 0.8084 - val_loss: 0.4094 - learning_rate: 5.0000e-04
# Epoch 31/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8571 - loss: 0.3627 - val_accuracy: 0.8416 - val_loss: 0.3802 - learning_rate: 5.0000e-04
# Epoch 32/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - accuracy: 0.8571 - loss: 0.3626 - val_accuracy: 0.7602 - val_loss: 0.4449 - learning_rate: 5.0000e-04
# Epoch 33/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.8600 - loss: 0.3573 - val_accuracy: 0.7206 - val_loss: 0.6057 - learning_rate: 5.0000e-04
# Epoch 34/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 46s 13ms/step - accuracy: 0.8602 - loss: 0.3539 - val_accuracy: 0.7262 - val_loss: 0.6376 - learning_rate: 5.0000e-04
# Epoch 35/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 23s 12ms/step - accuracy: 0.8615 - loss: 0.3512 - val_accuracy: 0.6982 - val_loss: 0.7223 - learning_rate: 5.0000e-04
# Epoch 36/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 24s 12ms/step - accuracy: 0.8618 - loss: 0.3496 - val_accuracy: 0.7604 - val_loss: 0.5206 - learning_rate: 5.0000e-04
# Epoch 37/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 24s 12ms/step - accuracy: 0.8631 - loss: 0.3498 - val_accuracy: 0.7122 - val_loss: 0.6522 - learning_rate: 5.0000e-04
# Epoch 38/150
# 1991/1993 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8662 - loss: 0.3420
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 23s 12ms/step - accuracy: 0.8656 - loss: 0.3447 - val_accuracy: 0.7288 - val_loss: 0.5906 - learning_rate: 5.0000e-04
# Epoch 39/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 23s 12ms/step - accuracy: 0.8761 - loss: 0.3204 - val_accuracy: 0.7410 - val_loss: 0.5595 - learning_rate: 2.5000e-04
# Epoch 40/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 24s 12ms/step - accuracy: 0.8781 - loss: 0.3148 - val_accuracy: 0.7062 - val_loss: 0.8035 - learning_rate: 2.5000e-04
# Epoch 41/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 23s 12ms/step - accuracy: 0.8777 - loss: 0.3147 - val_accuracy: 0.7864 - val_loss: 0.4457 - learning_rate: 2.5000e-04
# Epoch 42/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 23s 12ms/step - accuracy: 0.8778 - loss: 0.3142 - val_accuracy: 0.7067 - val_loss: 0.8060 - learning_rate: 2.5000e-04
# Epoch 43/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 24s 12ms/step - accuracy: 0.8799 - loss: 0.3120 - val_accuracy: 0.7044 - val_loss: 0.8480 - learning_rate: 2.5000e-04
# Epoch 44/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 24s 12ms/step - accuracy: 0.8794 - loss: 0.3146 - val_accuracy: 0.7188 - val_loss: 0.5891 - learning_rate: 2.5000e-04
# Epoch 45/150
# 1991/1993 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8782 - loss: 0.3113
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 24s 12ms/step - accuracy: 0.8813 - loss: 0.3076 - val_accuracy: 0.7045 - val_loss: 0.6238 - learning_rate: 2.5000e-04
# Epoch 46/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 24s 12ms/step - accuracy: 0.8869 - loss: 0.2973 - val_accuracy: 0.7035 - val_loss: 0.7747 - learning_rate: 1.2500e-04
# Epoch 47/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 24s 12ms/step - accuracy: 0.8901 - loss: 0.2898 - val_accuracy: 0.7043 - val_loss: 0.7998 - learning_rate: 1.2500e-04
# Epoch 48/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 24s 12ms/step - accuracy: 0.8892 - loss: 0.2928 - val_accuracy: 0.7099 - val_loss: 0.6020 - learning_rate: 1.2500e-04
# Epoch 49/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 24s 12ms/step - accuracy: 0.8905 - loss: 0.2911 - val_accuracy: 0.6955 - val_loss: 0.9184 - learning_rate: 1.2500e-04
# Epoch 50/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 24s 12ms/step - accuracy: 0.8889 - loss: 0.2914 - val_accuracy: 0.6875 - val_loss: 0.7849 - learning_rate: 1.2500e-04
# Epoch 51/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 25s 12ms/step - accuracy: 0.8900 - loss: 0.2905 - val_accuracy: 0.6864 - val_loss: 0.9471 - learning_rate: 1.2500e-04
# Epoch 51: early stopping
# Restoring model weights from the end of the best epoch: 31.
# \n✅ Entrenamiento completado
# 📈 Épocas entrenadas: 51

# %%
# Gráficas de entrenamiento - Dataset Original
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Loss
axes[0].plot(history_original.history['loss'], label='Train Loss', linewidth=2)
axes[0].plot(history_original.history['val_loss'], label='Val Loss', linewidth=2)
axes[0].set_title('Pérdida durante el Entrenamiento - Original', fontweight='bold', fontsize=12)
axes[0].set_xlabel('Época')
axes[0].set_ylabel('Loss')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Accuracy
axes[1].plot(history_original.history['accuracy'], label='Train Accuracy', linewidth=2)
axes[1].plot(history_original.history['val_accuracy'], label='Val Accuracy', linewidth=2)
axes[1].set_title('Precisión durante el Entrenamiento - Original', fontweight='bold', fontsize=12)
axes[1].set_xlabel('Época')
axes[1].set_ylabel('Accuracy')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f'📈 Entrenamiento detenido en época {len(history_original.history["loss"])}')
# Out:
# 📈 Entrenamiento detenido en época 51

# %% [markdown]
# ### 📊 Evaluación - Dataset Original

# %%
# Predicciones en conjunto de prueba
y_pred_orig = modelo_original.predict(X_test_orig_scaled)
y_pred_orig_classes = np.argmax(y_pred_orig, axis=1)

# Métricas
accuracy_orig = accuracy_score(y_test_orig, y_pred_orig_classes)
precision_orig = precision_score(y_test_orig, y_pred_orig_classes, average='weighted', zero_division=0)
recall_orig = recall_score(y_test_orig, y_pred_orig_classes, average='weighted', zero_division=0)
f1_orig = f1_score(y_test_orig, y_pred_orig_classes, average='weighted', zero_division=0)

print('='*60)
print('📊 RESULTADOS - DATASET ORIGINAL')
print('='*60)
print(f'\\n✅ Accuracy:  {accuracy_orig:.4f} ({accuracy_orig*100:.2f}%)')
print(f'✅ Precision: {precision_orig:.4f}')
print(f'✅ Recall:    {recall_orig:.4f}')
print(f'✅ F1-Score:  {f1_orig:.4f}')

print('\\n' + '='*60)
print('📋 REPORTE DE CLASIFICACIÓN - DATASET ORIGINAL')
print('='*60 + '\\n')
print(classification_report(y_test_orig, y_pred_orig_classes, 
                          target_names=le_target.classes_, 
                          zero_division=0))
# Out:
# 623/623 ━━━━━━━━━━━━━━━━━━━━ 1s 952us/step
# ============================================================
# 📊 RESULTADOS - DATASET ORIGINAL
# ============================================================
# \n✅ Accuracy:  0.8399 (83.99%)
# ✅ Precision: 0.8538
# ✅ Recall:    0.8399
# ✅ F1-Score:  0.8441
# \n============================================================
# 📋 REPORTE DE CLASIFICACIÓN - DATASET ORIGINAL
# ============================================================\n
#               precision    recall  f1-score   support
#
#         Alto       0.84      0.92      0.88      6055
#         Bajo       0.94      0.84      0.89     10967
#        Medio       0.56      0.67      0.61      2899
#
#     accuracy                           0.84     19921
#    macro avg       0.78      0.81      0.79     19921
# weighted avg       0.85      0.84      0.84     19921

# %%
# Evaluación modelo original
y_pred_orig = modelo_original.predict(X_test_orig_scaled)
y_pred_orig_classes = np.argmax(y_pred_orig, axis=1)

accuracy_orig = accuracy_score(y_test_orig, y_pred_orig_classes)
precision_orig = precision_score(y_test_orig, y_pred_orig_classes, average='weighted')
recall_orig = recall_score(y_test_orig, y_pred_orig_classes, average='weighted')
f1_orig = f1_score(y_test_orig, y_pred_orig_classes, average='weighted')

print('='*60)
print('MODELO ORIGINAL - RESULTADOS')
print('='*60)
print(f'Accuracy:  {accuracy_orig:.4f}')
print(f'Precision: {precision_orig:.4f}')
print(f'Recall:    {recall_orig:.4f}')
print(f'F1-Score:  {f1_orig:.4f}')

print('\nReporte de Clasificación:')
print(classification_report(y_test_orig, y_pred_orig_classes, target_names=le_target.classes_))

# Matriz de confusión
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

cm = confusion_matrix(y_test_orig, y_pred_orig_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=le_target.classes_, 
            yticklabels=le_target.classes_)
plt.title('Matriz de Confusión - Modelo Original')
plt.ylabel('Clase Real')
plt.xlabel('Clase Predicha')
plt.tight_layout()
plt.show()

print('\nMatriz de Confusión:')
print(cm)
# Out:
# 623/623 ━━━━━━━━━━━━━━━━━━━━ 1s 916us/step
# ============================================================
# MODELO ORIGINAL - RESULTADOS
# ============================================================
# Accuracy:  0.8399
# Precision: 0.8538
# Recall:    0.8399
# F1-Score:  0.8441
#
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#         Alto       0.84      0.92      0.88      6055
#         Bajo       0.94      0.84      0.89     10967
#        Medio       0.56      0.67      0.61      2899
#
#     accuracy                           0.84     19921
#    macro avg       0.78      0.81      0.79     19921
# weighted avg       0.85      0.84      0.84     19921
# Matriz de Confusión:
# [[5574  285  196]
#  [ 395 9225 1347]
#  [ 658  309 1932]]

# %% [markdown]
# ---
# ### 🔐 Preparación de Datos - Dataset Anonimizado

# %%
# Preparar dataset anonimizado
df_anon = df_anonimizado.copy()

print(f'Dataset anonimizado cargado: {df_anon.shape[0]:,} filas')

# NO hacer dropna general, solo limpiar nulls críticos si existen
if 'RMU_PUESTO' in df_anon.columns:
    df_anon = df_anon.dropna(subset=['RMU_PUESTO', 'CATEGORIA_SUELDO'])
    print(f'Después de limpiar nulls: {df_anon.shape[0]:,} filas')

# Verificar que tenemos el target correcto
if 'CATEGORIA_SUELDO' not in df_anon.columns:
    print('ERROR: CATEGORIA_SUELDO no existe en dataset anonimizado')
else:
    # Regenerar categorías con 3 clases
    percentiles_anon = df_anon['RMU_PUESTO'].quantile([0.33, 0.66]).values
    df_anon['CATEGORIA_SUELDO'] = df_anon['RMU_PUESTO'].apply(
        lambda x: 'Bajo' if x <= percentiles_anon[0] else ('Medio' if x <= percentiles_anon[1] else 'Alto')
    )
    
    print(f'Clases: {df_anon["CATEGORIA_SUELDO"].unique()}')
    print(f'Distribución: {df_anon["CATEGORIA_SUELDO"].value_counts().to_dict()}')
    
    # Separar features y target
    X_anon = df_anon.drop(['CATEGORIA_SUELDO', 'RMU_PUESTO'], axis=1)
    y_anon = df_anon['CATEGORIA_SUELDO']
    
    numeric_cols_anon = X_anon.select_dtypes(include=['int64', 'float64']).columns.tolist()
    categorical_cols_anon = X_anon.select_dtypes(include=['object']).columns.tolist()
    
    print(f'Features: {len(numeric_cols_anon)} numéricas, {len(categorical_cols_anon)} categóricas')
    print(f'X_anon shape: {X_anon.shape}, y_anon shape: {y_anon.shape}')
# Out:
# Dataset anonimizado cargado: 99,629 filas
# Después de limpiar nulls: 99,629 filas
# Clases: ['Bajo' 'Medio' 'Alto']
# Distribución: {'Bajo': 54853, 'Alto': 30279, 'Medio': 14497}
# Features: 2 numéricas, 16 categóricas
# X_anon shape: (99629, 19), y_anon shape: (99629,)

# %%
# Encoding dataset anonimizado
X_anon_encoded = X_anon.copy()

print(f'Encoding {len(categorical_cols_anon)} columnas categóricas...')

label_encoders_anon = {}
for col in categorical_cols_anon:
    le = LabelEncoder()
    X_anon_encoded[col] = le.fit_transform(X_anon_encoded[col].astype(str))
    label_encoders_anon[col] = le

# Encoding del target usando el mismo encoder del dataset original
y_anon_encoded = le_target.transform(y_anon)

print(f'Target: {len(le_target.classes_)} clases → {le_target.classes_}')
print(f'Labels únicos: {np.unique(y_anon_encoded)}')
print(f'Shape antes de split: X={X_anon_encoded.shape}, y={y_anon_encoded.shape}')

# Verificación
if len(X_anon_encoded) == 0:
    print('ERROR: Dataset vacío!')
else:
    # División train/test
    X_train_anon, X_test_anon, y_train_anon, y_test_anon = train_test_split(
        X_anon_encoded, y_anon_encoded, test_size=0.2, random_state=42, stratify=y_anon_encoded
    )
    
    # Normalización
    scaler_anon = StandardScaler()
    X_train_anon_scaled = scaler_anon.fit_transform(X_train_anon)
    X_test_anon_scaled = scaler_anon.transform(X_test_anon)
    
    print(f'Train: {X_train_anon_scaled.shape[0]:,} | Test: {X_test_anon_scaled.shape[0]:,}')
# Out:
# Encoding 16 columnas categóricas...
# Target: 3 clases → ['Alto' 'Bajo' 'Medio']
# Labels únicos: [0 1 2]
# Shape antes de split: X=(99629, 19), y=(99629,)
# Train: 79,703 | Test: 19,926

# %%
# Crear modelo MEJORADO para dataset anonimizado
input_dim_anon = X_train_anon_scaled.shape[1]
modelo_anonimizado = crear_modelo(input_dim_anon, num_clases=3)

# Callbacks
early_stopping_anon = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=20,
    restore_best_weights=True,
    verbose=1
)

reduce_lr_anon = keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=7,
    min_lr=1e-7,
    verbose=1
)

# Entrenar modelo
print('🚀 ENTRENANDO RED NEURONAL MEJORADA CON DATASET ANONIMIZADO...\\n')
print('📊 Configuración:')
print(f'   - Arquitectura: 5 capas ocultas (256→128→128→64→32)')
print(f'   - Clases: 3 (Bajo, Medio, Alto)')
print(f'   - Épocas máximas: 150')
print('\\n')

history_anonimizado = modelo_anonimizado.fit(
    X_train_anon_scaled, y_train_anon,
    validation_split=0.2,
    epochs=150,
    batch_size=32,
    callbacks=[early_stopping_anon, reduce_lr_anon],
    verbose=1
)

print('\\n✅ Entrenamiento completado')
print(f'📈 Épocas entrenadas: {len(history_anonimizado.history["loss"])}')
# Out:
# 🚀 ENTRENANDO RED NEURONAL MEJORADA CON DATASET ANONIMIZADO...\n
# 📊 Configuración:
#    - Arquitectura: 5 capas ocultas (256→128→128→64→32)
#    - Clases: 3 (Bajo, Medio, Alto)
#    - Épocas máximas: 150
# \n
# Epoch 1/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6591 - loss: 0.7748 - val_accuracy: 0.7077 - val_loss: 0.6389 - learning_rate: 0.0010
# Epoch 2/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.6935 - loss: 0.6759 - val_accuracy: 0.7096 - val_loss: 0.6311 - learning_rate: 0.0010
# Epoch 3/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.6989 - loss: 0.6508 - val_accuracy: 0.7151 - val_loss: 0.6131 - learning_rate: 0.0010
# Epoch 4/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7029 - loss: 0.6400 - val_accuracy: 0.7158 - val_loss: 0.6065 - learning_rate: 0.0010
# Epoch 5/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7068 - loss: 0.6320 - val_accuracy: 0.7162 - val_loss: 0.6007 - learning_rate: 0.0010
# Epoch 6/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7123 - loss: 0.6235 - val_accuracy: 0.7203 - val_loss: 0.5935 - learning_rate: 0.0010
# Epoch 7/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7279 - loss: 0.6060 - val_accuracy: 0.7434 - val_loss: 0.5773 - learning_rate: 0.0010
# Epoch 8/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7551 - loss: 0.5669 - val_accuracy: 0.6664 - val_loss: 0.6102 - learning_rate: 0.0010
# Epoch 9/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7691 - loss: 0.5411 - val_accuracy: 0.6651 - val_loss: 0.6397 - learning_rate: 0.0010
# Epoch 10/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7775 - loss: 0.5216 - val_accuracy: 0.6644 - val_loss: 0.8513 - learning_rate: 0.0010
# Epoch 11/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7860 - loss: 0.5071 - val_accuracy: 0.6632 - val_loss: 0.8685 - learning_rate: 0.0010
# Epoch 12/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.7913 - loss: 0.4957 - val_accuracy: 0.6625 - val_loss: 0.7143 - learning_rate: 0.0010
# Epoch 13/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8010 - loss: 0.4780 - val_accuracy: 0.6631 - val_loss: 0.6965 - learning_rate: 0.0010
# Epoch 14/150
# 1989/1993 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8078 - loss: 0.4672
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8060 - loss: 0.4704 - val_accuracy: 0.6646 - val_loss: 0.8810 - learning_rate: 0.0010
# Epoch 15/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8225 - loss: 0.4327 - val_accuracy: 0.6130 - val_loss: 1.0057 - learning_rate: 5.0000e-04
# Epoch 16/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8282 - loss: 0.4217 - val_accuracy: 0.6786 - val_loss: 0.8643 - learning_rate: 5.0000e-04
# Epoch 17/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8304 - loss: 0.4196 - val_accuracy: 0.6370 - val_loss: 0.9450 - learning_rate: 5.0000e-04
# Epoch 18/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8346 - loss: 0.4119 - val_accuracy: 0.6061 - val_loss: 1.0227 - learning_rate: 5.0000e-04
# Epoch 19/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8341 - loss: 0.4129 - val_accuracy: 0.6389 - val_loss: 0.8612 - learning_rate: 5.0000e-04
# Epoch 20/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8381 - loss: 0.4052 - val_accuracy: 0.6551 - val_loss: 0.8943 - learning_rate: 5.0000e-04
# Epoch 21/150
# 1991/1993 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8395 - loss: 0.4046
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8399 - loss: 0.4038 - val_accuracy: 0.6357 - val_loss: 1.0213 - learning_rate: 5.0000e-04
# Epoch 22/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8506 - loss: 0.3813 - val_accuracy: 0.6650 - val_loss: 1.0667 - learning_rate: 2.5000e-04
# Epoch 23/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8534 - loss: 0.3775 - val_accuracy: 0.6988 - val_loss: 1.0107 - learning_rate: 2.5000e-04
# Epoch 24/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8538 - loss: 0.3755 - val_accuracy: 0.6947 - val_loss: 1.0857 - learning_rate: 2.5000e-04
# Epoch 25/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8558 - loss: 0.3751 - val_accuracy: 0.6990 - val_loss: 0.8939 - learning_rate: 2.5000e-04
# Epoch 26/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8576 - loss: 0.3687 - val_accuracy: 0.6897 - val_loss: 1.1459 - learning_rate: 2.5000e-04
# Epoch 27/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8565 - loss: 0.3681 - val_accuracy: 0.6721 - val_loss: 1.1286 - learning_rate: 2.5000e-04
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 7.
# \n✅ Entrenamiento completado
# 📈 Épocas entrenadas: 27

# %%
# Gráficas de entrenamiento - Dataset Anonimizado
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Loss
axes[0].plot(history_anonimizado.history['loss'], label='Train Loss', linewidth=2)
axes[0].plot(history_anonimizado.history['val_loss'], label='Val Loss', linewidth=2)
axes[0].set_title('Pérdida durante el Entrenamiento - Anonimizado', fontweight='bold', fontsize=12)
axes[0].set_xlabel('Época')
axes[0].set_ylabel('Loss')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Accuracy
axes[1].plot(history_anonimizado.history['accuracy'], label='Train Accuracy', linewidth=2)
axes[1].plot(history_anonimizado.history['val_accuracy'], label='Val Accuracy', linewidth=2)
axes[1].set_title('Precisión durante el Entrenamiento - Anonimizado', fontweight='bold', fontsize=12)
axes[1].set_xlabel('Época')
axes[1].set_ylabel('Accuracy')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f'📈 Entrenamiento detenido en época {len(history_anonimizado.history["loss"])}')
# Out:
# 📈 Entrenamiento detenido en época 27

# %% [markdown]
# ### 📊 Evaluación - Dataset Anonimizado

# %%
# Predicciones en conjunto de prueba
y_pred_anon = modelo_anonimizado.predict(X_test_anon_scaled)
y_pred_anon_classes = np.argmax(y_pred_anon, axis=1)

# Métricas
accuracy_anon = accuracy_score(y_test_anon, y_pred_anon_classes)
precision_anon = precision_score(y_test_anon, y_pred_anon_classes, average='weighted', zero_division=0)
recall_anon = recall_score(y_test_anon, y_pred_anon_classes, average='weighted', zero_division=0)
f1_anon = f1_score(y_test_anon, y_pred_anon_classes, average='weighted', zero_division=0)

print('='*60)
print('📊 RESULTADOS - DATASET ANONIMIZADO')
print('='*60)
print(f'\\n✅ Accuracy:  {accuracy_anon:.4f} ({accuracy_anon*100:.2f}%)')
print(f'✅ Precision: {precision_anon:.4f}')
print(f'✅ Recall:    {recall_anon:.4f}')
print(f'✅ F1-Score:  {f1_anon:.4f}')

print('\\n' + '='*60)
print('📋 REPORTE DE CLASIFICACIÓN - DATASET ANONIMIZADO')
print('='*60 + '\\n')
print(classification_report(y_test_anon, y_pred_anon_classes, 
                          target_names=le_target.classes_, 
                          zero_division=0))
# Out:
# 623/623 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# ============================================================
# 📊 RESULTADOS - DATASET ANONIMIZADO
# ============================================================
# \n✅ Accuracy:  0.7392 (73.92%)
# ✅ Precision: 0.6451
# ✅ Recall:    0.7392
# ✅ F1-Score:  0.6779
# \n============================================================
# 📋 REPORTE DE CLASIFICACIÓN - DATASET ANONIMIZADO
# ============================================================\n
#               precision    recall  f1-score   support
#
#         Alto       0.85      0.68      0.75      6056
#         Bajo       0.70      0.97      0.82     10971
#        Medio       0.00      0.00      0.00      2899
#
#     accuracy                           0.74     19926
#    macro avg       0.52      0.55      0.52     19926
# weighted avg       0.65      0.74      0.68     19926

# %%
# Evaluación modelo anonimizado
y_pred_anon = modelo_anonimizado.predict(X_test_anon_scaled)
y_pred_anon_classes = np.argmax(y_pred_anon, axis=1)

accuracy_anon = accuracy_score(y_test_anon, y_pred_anon_classes)
precision_anon = precision_score(y_test_anon, y_pred_anon_classes, average='weighted')
recall_anon = recall_score(y_test_anon, y_pred_anon_classes, average='weighted')
f1_anon = f1_score(y_test_anon, y_pred_anon_classes, average='weighted')

print('='*60)
print('MODELO ANONIMIZADO - RESULTADOS')
print('='*60)
print(f'Accuracy:  {accuracy_anon:.4f}')
print(f'Precision: {precision_anon:.4f}')
print(f'Recall:    {recall_anon:.4f}')
print(f'F1-Score:  {f1_anon:.4f}')

print('\nReporte de Clasificación:')
print(classification_report(y_test_anon, y_pred_anon_classes, target_names=le_target.classes_))

# Matriz de confusión
cm_anon = confusion_matrix(y_test_anon, y_pred_anon_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm_anon, annot=True, fmt='d', cmap='Greens', 
            xticklabels=le_target.classes_, 
            yticklabels=le_target.classes_)
plt.title('Matriz de Confusión - Modelo Anonimizado')
plt.ylabel('Clase Real')
plt.xlabel('Clase Predicha')
plt.tight_layout()
plt.show()

print('\nMatriz de Confusión:')
print(cm_anon)
# Out:
# 623/623 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# ============================================================
# MODELO ANONIMIZADO - RESULTADOS
# ============================================================
# Accuracy:  0.7392
# Precision: 0.6451
# Recall:    0.7392
# F1-Score:  0.6779
#
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#         Alto       0.85      0.68      0.75      6056
#         Bajo       0.70      0.97      0.82     10971
#        Medio       0.00      0.00      0.00      2899
#
#     accuracy                           0.74     19926
#    macro avg       0.52      0.55      0.52     19926
# weighted avg       0.65      0.74      0.68     19926
# Matriz de Confusión:
# [[ 4106  1950     0]
#  [  348 10623     0]
#  [  401  2498     0]]

# %% [markdown]
# ---
# ### 📊 Comparación: Original vs Anonimizado

# %%
# Comparación de resultados
print('='*70)
print('COMPARACIÓN DE RESULTADOS')
print('='*70)
print(f'{"Métrica":<15} {"Original":<15} {"Anonimizado":<15} {"Diferencia":<15}')
print('-'*70)
print(f'{"Accuracy":<15} {accuracy_orig:<15.4f} {accuracy_anon:<15.4f} {(accuracy_orig-accuracy_anon):<15.4f}')
print(f'{"Precision":<15} {precision_orig:<15.4f} {precision_anon:<15.4f} {(precision_orig-precision_anon):<15.4f}')
print(f'{"Recall":<15} {recall_orig:<15.4f} {recall_anon:<15.4f} {(recall_orig-recall_anon):<15.4f}')
print(f'{"F1-Score":<15} {f1_orig:<15.4f} {f1_anon:<15.4f} {(f1_orig-f1_anon):<15.4f}')
print('='*70)

# Visualización comparativa
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Matriz original
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[0],
            xticklabels=le_target.classes_, yticklabels=le_target.classes_)
axes[0].set_title(f'Original\nAccuracy: {accuracy_orig:.2%}')
axes[0].set_ylabel('Clase Real')
axes[0].set_xlabel('Clase Predicha')

# Matriz anonimizada
sns.heatmap(cm_anon, annot=True, fmt='d', cmap='Greens', ax=axes[1],
            xticklabels=le_target.classes_, yticklabels=le_target.classes_)
axes[1].set_title(f'Anonimizado\nAccuracy: {accuracy_anon:.2%}')
axes[1].set_ylabel('Clase Real')
axes[1].set_xlabel('Clase Predicha')

plt.tight_layout()
plt.show()

# Trade-off privacidad vs utilidad
perdida_accuracy = accuracy_orig - accuracy_anon
porcentaje_perdida = (perdida_accuracy / accuracy_orig) * 100

print(f'\nTrade-off Privacidad-Utilidad:')
print(f'  Pérdida de accuracy: {perdida_accuracy:.4f} ({porcentaje_perdida:.2f}%)')
if porcentaje_perdida < 5:
    print(f'  ✅ Pérdida aceptable (<5%) - Buena anonimización')
elif porcentaje_perdida < 10:
    print(f'  ⚠️ Pérdida moderada (5-10%) - Anonimización razonable')
else:
    print(f'  ❌ Pérdida alta (>10%) - Revisar técnicas de anonimización')
# Out:
# ======================================================================
# COMPARACIÓN DE RESULTADOS
# ======================================================================
# Métrica         Original        Anonimizado     Diferencia
# ----------------------------------------------------------------------
# Accuracy        0.8399          0.7392          0.1007
# Precision       0.8538          0.6451          0.2087
# Recall          0.8399          0.7392          0.1007
# F1-Score        0.8441          0.6779          0.1661
# ======================================================================
# Trade-off Privacidad-Utilidad:
#   Pérdida de accuracy: 0.1007 (11.99%)
#   ❌ Pérdida alta (>10%) - Revisar técnicas de anonimización

# %% [markdown]
# ### Conclusiones Punto 4
#
# **Mejoras implementadas:**
# - Reducción de 4 a 3 clases (elimina solapamiento)
# - Arquitectura más profunda: 5 capas (256→128→128→64→32)
# - Dropout progresivo y BatchNormalization
# - CANTON mantenido (aporta $1,470 de diferencia)
#
# **Resultados:**
# - Dataset Original: {accuracy_orig:.2%} accuracy
# - Dataset Anonimizado: {accuracy_anon:.2%} accuracy
#
# **Trade-off**: Anonimización reduce información geográfica pero mantiene utilidad del modelo.

# %%
# Guardar modelos
modelo_original.save('modelo_original.h5')
modelo_anonimizado.save('modelo_anonimizado.h5')

resultados = {
    'original': {
        'accuracy': float(accuracy_orig),
        'precision': float(precision_orig),
        'recall': float(recall_orig),
        'f1_score': float(f1_orig)
    },
    'anonimizado': {
        'accuracy': float(accuracy_anon),
        'precision': float(precision_anon),
        'recall': float(recall_anon),
        'f1_score': float(f1_anon)
    }
}

import json
with open('resultados_punto4.json', 'w') as f:
    json.dump(resultados, f, indent=4)

print('✅ Modelos y resultados guardados')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Modelos y resultados guardados

# %%
# Imports para CTGAN
from sdv.single_table import CTGANSynthesizer
from sdv.metadata import SingleTableMetadata
import warnings
warnings.filterwarnings('ignore')

print('CTGAN importado correctamente')
# Out:
# CTGAN importado correctamente

# %%
# Preparar dataset original para CTGAN (incluir RMU_PUESTO para generar datos realistas)
df_for_ctgan = df_original_limpio.copy()

# Verificar
print(f'Dataset para CTGAN: {df_for_ctgan.shape}')
print(f'Columnas: {df_for_ctgan.columns.tolist()}')
print(f'Clases: {df_for_ctgan["CATEGORIA_SUELDO"].value_counts().to_dict()}')
# Out:
# Dataset para CTGAN: (99605, 15)
# Columnas: ['CATEGORIA_SUELDO', 'ACUMULA_DEC_CUARTO', 'NOMBRE_UNIDAD_ORGANIZACIONAL', 'NOMBRE_PROVINCIA', 'NOMBRE_NIVEL_OCUPACIONAL', 'NOMBRE_ESTADO_PUESTO', 'SECTOR_DESC', 'GENERO', 'ACUMULA_DEC_TERCERO', 'NOMBRE_REGIMEN_LABORAL', 'NOMBRE_DENOMINACION_PUESTO', 'RMU_PUESTO', 'NOMBRE_CANTON', 'EDAD', 'ANTIGUEDAD_DIAS']
# Clases: {'Bajo': 54835, 'Alto': 30273, 'Medio': 14497}

# %%
# Preparar datos reduciendo cardinalidad (CTGAN no puede con 9000 categorías)
df_for_ctgan = df_original_limpio.copy()

# Eliminar columnas con alta cardinalidad que CTGAN no puede manejar
cols_alta_cardinalidad = ['NOMBRE_UNIDAD_ORGANIZACIONAL', 'NOMBRE_DENOMINACION_PUESTO']
df_for_ctgan = df_for_ctgan.drop(columns=[c for c in cols_alta_cardinalidad if c in df_for_ctgan.columns])

print(f'Dataset para CTGAN: {df_for_ctgan.shape}')
print(f'Columnas: {df_for_ctgan.columns.tolist()}')
print(f'Clases: {df_for_ctgan["CATEGORIA_SUELDO"].value_counts().to_dict()}')

# Crear metadata
metadata = SingleTableMetadata()
metadata.detect_from_dataframe(df_for_ctgan)

# CTGAN con configuración para Windows (sin multiprocessing)
import os
os.environ['LOKY_MAX_CPU_COUNT'] = '1'  # Forzar single-core

synthesizer = CTGANSynthesizer(
    metadata,
    epochs=50,  # Reducido para que sea más rápido
    batch_size=500,
    verbose=True,
    cuda=False  # CPU only
)

# Entrenar CTGAN
print('\n🚀 Entrenando CTGAN (esto tarda ~5-10 minutos)...\n')

try:
    synthesizer.fit(df_for_ctgan)
    print('\n✅ CTGAN entrenado correctamente')
except Exception as e:
    print(f'\n❌ Error con CTGAN: {e}')
    print('\n🔄 Intentando con GaussianCopula (más simple, más rápido)...')
    
    # Plan B: GaussianCopula (más simple, funciona mejor en Windows)
    from sdv.single_table import GaussianCopulaSynthesizer
    
    synthesizer = GaussianCopulaSynthesizer(metadata)
    synthesizer.fit(df_for_ctgan)
    print('\n✅ GaussianCopula entrenado correctamente')
# Out:
# Dataset para CTGAN: (99605, 13)
# Columnas: ['CATEGORIA_SUELDO', 'ACUMULA_DEC_CUARTO', 'NOMBRE_PROVINCIA', 'NOMBRE_NIVEL_OCUPACIONAL', 'NOMBRE_ESTADO_PUESTO', 'SECTOR_DESC', 'GENERO', 'ACUMULA_DEC_TERCERO', 'NOMBRE_REGIMEN_LABORAL', 'RMU_PUESTO', 'NOMBRE_CANTON', 'EDAD', 'ANTIGUEDAD_DIAS']
# Clases: {'Bajo': 54835, 'Alto': 30273, 'Medio': 14497}
#
# 🚀 Entrenando CTGAN (esto tarda ~5-10 minutos)...
# Gen. (-0.36) | Discrim. (-0.23): 100%|██████████| 50/50 [2:04:03<00:00, 148.87s/it]
# ✅ CTGAN entrenado correctamente

# %%
# Generar datos sintéticos
num_samples = len(df_for_ctgan)

print(f'Generando {num_samples:,} muestras sintéticas...')
df_sintetico = synthesizer.sample(num_rows=num_samples)

# Agregar de vuelta las columnas eliminadas con valores dummy
for col in cols_alta_cardinalidad:
    if col in df_original_limpio.columns:
        # Asignar valores aleatorios de las categorías originales
        df_sintetico[col] = np.random.choice(
            df_original_limpio[col].unique(), 
            size=len(df_sintetico)
        )

print(f'\n✅ Datos sintéticos generados: {df_sintetico.shape}')
print(f'Clases sintéticas: {df_sintetico["CATEGORIA_SUELDO"].value_counts().to_dict()}')

df_sintetico.to_csv('df_sintetico.csv', index=False)
print('✅ Dataset sintético guardado')
# Out:
# Generando 99,605 muestras sintéticas...
#
# ✅ Datos sintéticos generados: (99605, 15)
# Clases sintéticas: {'Bajo': 47903, 'Alto': 35639, 'Medio': 16063}
# ✅ Dataset sintético guardado

# %%
# Preparar dataset sintético igual que el original
X_sintetico = df_sintetico.drop(['CATEGORIA_SUELDO', 'RMU_PUESTO'], axis=1)
y_sintetico = df_sintetico['CATEGORIA_SUELDO']

print(f'Dataset sintético preparado:')
print(f'  X shape: {X_sintetico.shape}')
print(f'  y shape: {y_sintetico.shape}')
print(f'  Clases: {y_sintetico.unique()}')

# Encoding (usar mismo proceso que dataset original)
X_sintetico_encoded = X_sintetico.copy()

categorical_cols_syn = X_sintetico.select_dtypes(include=['object']).columns.tolist()

for col in categorical_cols_syn:
    if col in label_encoders_original:
        le = label_encoders_original[col]
        # Manejar categorías nuevas que puedan aparecer en sintéticos
        X_sintetico_encoded[col] = X_sintetico_encoded[col].apply(
            lambda x: le.transform([str(x)])[0] if str(x) in le.classes_ else 0
        )
    else:
        le = LabelEncoder()
        X_sintetico_encoded[col] = le.fit_transform(X_sintetico_encoded[col].astype(str))

# Encoding del target
y_sintetico_encoded = le_target.transform(y_sintetico)

print(f'Target encoding: {len(le_target.classes_)} clases → {le_target.classes_}')
print(f'Labels únicos: {np.unique(y_sintetico_encoded)}')

# División train/test
X_train_syn, X_test_syn, y_train_syn, y_test_syn = train_test_split(
    X_sintetico_encoded, y_sintetico_encoded, 
    test_size=0.2, 
    random_state=42, 
    stratify=y_sintetico_encoded
)

# Normalización
scaler_syn = StandardScaler()
X_train_syn_scaled = scaler_syn.fit_transform(X_train_syn)
X_test_syn_scaled = scaler_syn.transform(X_test_syn)

print(f'Train: {X_train_syn_scaled.shape[0]:,} | Test: {X_test_syn_scaled.shape[0]:,}')
# Out:
# Dataset sintético preparado:
#   X shape: (99605, 13)
#   y shape: (99605,)
#   Clases: ['Bajo' 'Alto' 'Medio']
# Target encoding: 3 clases → ['Alto' 'Bajo' 'Medio']
# Labels únicos: [0 1 2]
# Train: 79,684 | Test: 19,921

# %%
# Crear modelo para datos sintéticos (misma arquitectura)
input_dim_syn = X_train_syn_scaled.shape[1]
modelo_sintetico = crear_modelo(input_dim_syn, num_clases=3)

# Callbacks
early_stopping_syn = keras.callbacks.EarlyStopping(
    monitor='val_loss', 
    patience=20, 
    restore_best_weights=True, 
    verbose=1
)
reduce_lr_syn = keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.5, 
    patience=7, 
    min_lr=1e-7, 
    verbose=1
)

# Entrenar
print('Entrenando modelo con datos sintéticos...')
history_sintetico = modelo_sintetico.fit(
    X_train_syn_scaled, y_train_syn,
    validation_split=0.2,
    epochs=150,
    batch_size=32,
    callbacks=[early_stopping_syn, reduce_lr_syn],
    verbose=1
)

print(f'✅ Entrenamiento completado - {len(history_sintetico.history["loss"])} épocas')
# Out:
# Entrenando modelo con datos sintéticos...
# Epoch 1/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.6597 - loss: 0.8352 - val_accuracy: 0.7058 - val_loss: 0.7054 - learning_rate: 0.0010
# Epoch 2/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.6983 - loss: 0.7345 - val_accuracy: 0.7203 - val_loss: 0.6516 - learning_rate: 0.0010
# Epoch 3/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7097 - loss: 0.6965 - val_accuracy: 0.7236 - val_loss: 0.6432 - learning_rate: 0.0010
# Epoch 4/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7135 - loss: 0.6820 - val_accuracy: 0.7237 - val_loss: 0.6411 - learning_rate: 0.0010
# Epoch 5/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.7159 - loss: 0.6745 - val_accuracy: 0.7266 - val_loss: 0.6348 - learning_rate: 0.0010
# Epoch 6/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7198 - loss: 0.6681 - val_accuracy: 0.7262 - val_loss: 0.6331 - learning_rate: 0.0010
# Epoch 7/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.7205 - loss: 0.6634 - val_accuracy: 0.7276 - val_loss: 0.6298 - learning_rate: 0.0010
# Epoch 8/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - accuracy: 0.7208 - loss: 0.6615 - val_accuracy: 0.7274 - val_loss: 0.6274 - learning_rate: 0.0010
# Epoch 9/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.7223 - loss: 0.6579 - val_accuracy: 0.7279 - val_loss: 0.6295 - learning_rate: 0.0010
# Epoch 10/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - accuracy: 0.7227 - loss: 0.6557 - val_accuracy: 0.7274 - val_loss: 0.6277 - learning_rate: 0.0010
# Epoch 11/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7234 - loss: 0.6559 - val_accuracy: 0.7260 - val_loss: 0.6266 - learning_rate: 0.0010
# Epoch 12/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7240 - loss: 0.6523 - val_accuracy: 0.7294 - val_loss: 0.6229 - learning_rate: 0.0010
# Epoch 13/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7233 - loss: 0.6518 - val_accuracy: 0.7301 - val_loss: 0.6249 - learning_rate: 0.0010
# Epoch 14/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.7239 - loss: 0.6517 - val_accuracy: 0.7269 - val_loss: 0.6250 - learning_rate: 0.0010
# Epoch 15/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.7242 - loss: 0.6498 - val_accuracy: 0.7300 - val_loss: 0.6252 - learning_rate: 0.0010
# Epoch 16/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.7252 - loss: 0.6477 - val_accuracy: 0.7306 - val_loss: 0.6229 - learning_rate: 0.0010
# Epoch 17/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7243 - loss: 0.6486 - val_accuracy: 0.7296 - val_loss: 0.6232 - learning_rate: 0.0010
# Epoch 18/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.7264 - loss: 0.6459 - val_accuracy: 0.7290 - val_loss: 0.6227 - learning_rate: 0.0010
# Epoch 19/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7265 - loss: 0.6450 - val_accuracy: 0.7297 - val_loss: 0.6219 - learning_rate: 0.0010
# Epoch 20/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7266 - loss: 0.6441 - val_accuracy: 0.7306 - val_loss: 0.6232 - learning_rate: 0.0010
# Epoch 21/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7258 - loss: 0.6443 - val_accuracy: 0.7299 - val_loss: 0.6205 - learning_rate: 0.0010
# Epoch 22/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7259 - loss: 0.6422 - val_accuracy: 0.7311 - val_loss: 0.6191 - learning_rate: 0.0010
# Epoch 23/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7270 - loss: 0.6428 - val_accuracy: 0.7290 - val_loss: 0.6191 - learning_rate: 0.0010
# Epoch 24/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7279 - loss: 0.6419 - val_accuracy: 0.7319 - val_loss: 0.6197 - learning_rate: 0.0010
# Epoch 25/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7261 - loss: 0.6429 - val_accuracy: 0.7323 - val_loss: 0.6205 - learning_rate: 0.0010
# Epoch 26/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7275 - loss: 0.6420 - val_accuracy: 0.7326 - val_loss: 0.6185 - learning_rate: 0.0010
# Epoch 27/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7281 - loss: 0.6398 - val_accuracy: 0.7316 - val_loss: 0.6191 - learning_rate: 0.0010
# Epoch 28/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7265 - loss: 0.6409 - val_accuracy: 0.7318 - val_loss: 0.6172 - learning_rate: 0.0010
# Epoch 29/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7271 - loss: 0.6399 - val_accuracy: 0.7316 - val_loss: 0.6179 - learning_rate: 0.0010
# Epoch 30/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7274 - loss: 0.6390 - val_accuracy: 0.7314 - val_loss: 0.6169 - learning_rate: 0.0010
# Epoch 31/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7280 - loss: 0.6388 - val_accuracy: 0.7315 - val_loss: 0.6183 - learning_rate: 0.0010
# Epoch 32/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7275 - loss: 0.6382 - val_accuracy: 0.7326 - val_loss: 0.6152 - learning_rate: 0.0010
# Epoch 33/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7282 - loss: 0.6374 - val_accuracy: 0.7334 - val_loss: 0.6195 - learning_rate: 0.0010
# Epoch 34/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7286 - loss: 0.6362 - val_accuracy: 0.7321 - val_loss: 0.6142 - learning_rate: 0.0010
# Epoch 35/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7281 - loss: 0.6362 - val_accuracy: 0.7317 - val_loss: 0.6128 - learning_rate: 0.0010
# Epoch 36/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7285 - loss: 0.6349 - val_accuracy: 0.7329 - val_loss: 0.6141 - learning_rate: 0.0010
# Epoch 37/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7295 - loss: 0.6335 - val_accuracy: 0.7320 - val_loss: 0.6138 - learning_rate: 0.0010
# Epoch 38/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7289 - loss: 0.6345 - val_accuracy: 0.7353 - val_loss: 0.6124 - learning_rate: 0.0010
# Epoch 39/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7302 - loss: 0.6340 - val_accuracy: 0.7310 - val_loss: 0.6118 - learning_rate: 0.0010
# Epoch 40/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.7295 - loss: 0.6326 - val_accuracy: 0.7328 - val_loss: 0.6112 - learning_rate: 0.0010
# Epoch 41/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7302 - loss: 0.6320 - val_accuracy: 0.7328 - val_loss: 0.6104 - learning_rate: 0.0010
# Epoch 42/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7308 - loss: 0.6321 - val_accuracy: 0.7329 - val_loss: 0.6116 - learning_rate: 0.0010
# Epoch 43/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7300 - loss: 0.6304 - val_accuracy: 0.7359 - val_loss: 0.6096 - learning_rate: 0.0010
# Epoch 44/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7310 - loss: 0.6318 - val_accuracy: 0.7339 - val_loss: 0.6103 - learning_rate: 0.0010
# Epoch 45/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.7302 - loss: 0.6307 - val_accuracy: 0.7355 - val_loss: 0.6118 - learning_rate: 0.0010
# Epoch 46/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7305 - loss: 0.6308 - val_accuracy: 0.7349 - val_loss: 0.6102 - learning_rate: 0.0010
# Epoch 47/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7307 - loss: 0.6309 - val_accuracy: 0.7326 - val_loss: 0.6103 - learning_rate: 0.0010
# Epoch 48/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7308 - loss: 0.6297 - val_accuracy: 0.7346 - val_loss: 0.6091 - learning_rate: 0.0010
# Epoch 49/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7304 - loss: 0.6295 - val_accuracy: 0.7350 - val_loss: 0.6087 - learning_rate: 0.0010
# Epoch 50/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7308 - loss: 0.6287 - val_accuracy: 0.7356 - val_loss: 0.6096 - learning_rate: 0.0010
# Epoch 51/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7318 - loss: 0.6273 - val_accuracy: 0.7351 - val_loss: 0.6070 - learning_rate: 0.0010
# Epoch 52/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7322 - loss: 0.6290 - val_accuracy: 0.7353 - val_loss: 0.6080 - learning_rate: 0.0010
# Epoch 53/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7313 - loss: 0.6297 - val_accuracy: 0.7346 - val_loss: 0.6070 - learning_rate: 0.0010
# Epoch 54/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7310 - loss: 0.6295 - val_accuracy: 0.7351 - val_loss: 0.6104 - learning_rate: 0.0010
# Epoch 55/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7326 - loss: 0.6259 - val_accuracy: 0.7347 - val_loss: 0.6086 - learning_rate: 0.0010
# Epoch 56/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7321 - loss: 0.6265 - val_accuracy: 0.7350 - val_loss: 0.6073 - learning_rate: 0.0010
# Epoch 57/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7318 - loss: 0.6263 - val_accuracy: 0.7356 - val_loss: 0.6093 - learning_rate: 0.0010
# Epoch 58/150
# 1984/1993 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7314 - loss: 0.6262
# Epoch 58: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.7319 - loss: 0.6267 - val_accuracy: 0.7345 - val_loss: 0.6086 - learning_rate: 0.0010
# Epoch 59/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7326 - loss: 0.6251 - val_accuracy: 0.7355 - val_loss: 0.6055 - learning_rate: 5.0000e-04
# Epoch 60/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7324 - loss: 0.6225 - val_accuracy: 0.7371 - val_loss: 0.6049 - learning_rate: 5.0000e-04
# Epoch 61/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.7326 - loss: 0.6224 - val_accuracy: 0.7366 - val_loss: 0.6044 - learning_rate: 5.0000e-04
# Epoch 62/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7338 - loss: 0.6227 - val_accuracy: 0.7368 - val_loss: 0.6043 - learning_rate: 5.0000e-04
# Epoch 63/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.7336 - loss: 0.6222 - val_accuracy: 0.7378 - val_loss: 0.6042 - learning_rate: 5.0000e-04
# Epoch 64/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.7341 - loss: 0.6214 - val_accuracy: 0.7368 - val_loss: 0.6034 - learning_rate: 5.0000e-04
# Epoch 65/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.7334 - loss: 0.6197 - val_accuracy: 0.7367 - val_loss: 0.6035 - learning_rate: 5.0000e-04
# Epoch 66/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.7333 - loss: 0.6205 - val_accuracy: 0.7379 - val_loss: 0.6031 - learning_rate: 5.0000e-04
# Epoch 67/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.7353 - loss: 0.6194 - val_accuracy: 0.7425 - val_loss: 0.6026 - learning_rate: 5.0000e-04
# Epoch 68/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7339 - loss: 0.6215 - val_accuracy: 0.7382 - val_loss: 0.6014 - learning_rate: 5.0000e-04
# Epoch 69/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7353 - loss: 0.6214 - val_accuracy: 0.7380 - val_loss: 0.6017 - learning_rate: 5.0000e-04
# Epoch 70/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7352 - loss: 0.6200 - val_accuracy: 0.7373 - val_loss: 0.6019 - learning_rate: 5.0000e-04
# Epoch 71/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7349 - loss: 0.6199 - val_accuracy: 0.7409 - val_loss: 0.6013 - learning_rate: 5.0000e-04
# Epoch 72/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7343 - loss: 0.6199 - val_accuracy: 0.7371 - val_loss: 0.6019 - learning_rate: 5.0000e-04
# Epoch 73/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7353 - loss: 0.6194 - val_accuracy: 0.7393 - val_loss: 0.6013 - learning_rate: 5.0000e-04
# Epoch 74/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7358 - loss: 0.6180 - val_accuracy: 0.7440 - val_loss: 0.6005 - learning_rate: 5.0000e-04
# Epoch 75/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7352 - loss: 0.6190 - val_accuracy: 0.7393 - val_loss: 0.6010 - learning_rate: 5.0000e-04
# Epoch 76/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7353 - loss: 0.6194 - val_accuracy: 0.7419 - val_loss: 0.6015 - learning_rate: 5.0000e-04
# Epoch 77/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7343 - loss: 0.6169 - val_accuracy: 0.7385 - val_loss: 0.6015 - learning_rate: 5.0000e-04
# Epoch 78/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7358 - loss: 0.6178 - val_accuracy: 0.7429 - val_loss: 0.6020 - learning_rate: 5.0000e-04
# Epoch 79/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7353 - loss: 0.6177 - val_accuracy: 0.7404 - val_loss: 0.5996 - learning_rate: 5.0000e-04
# Epoch 80/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7360 - loss: 0.6187 - val_accuracy: 0.7412 - val_loss: 0.6004 - learning_rate: 5.0000e-04
# Epoch 81/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7359 - loss: 0.6190 - val_accuracy: 0.7424 - val_loss: 0.5996 - learning_rate: 5.0000e-04
# Epoch 82/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7373 - loss: 0.6169 - val_accuracy: 0.7426 - val_loss: 0.5999 - learning_rate: 5.0000e-04
# Epoch 83/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7373 - loss: 0.6167 - val_accuracy: 0.7425 - val_loss: 0.5995 - learning_rate: 5.0000e-04
# Epoch 84/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7357 - loss: 0.6170 - val_accuracy: 0.7420 - val_loss: 0.5995 - learning_rate: 5.0000e-04
# Epoch 85/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7363 - loss: 0.6180 - val_accuracy: 0.7437 - val_loss: 0.6000 - learning_rate: 5.0000e-04
# Epoch 86/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7354 - loss: 0.6176 - val_accuracy: 0.7435 - val_loss: 0.5986 - learning_rate: 5.0000e-04
# Epoch 87/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7369 - loss: 0.6161 - val_accuracy: 0.7442 - val_loss: 0.5989 - learning_rate: 5.0000e-04
# Epoch 88/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7368 - loss: 0.6163 - val_accuracy: 0.7422 - val_loss: 0.5984 - learning_rate: 5.0000e-04
# Epoch 89/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7365 - loss: 0.6184 - val_accuracy: 0.7421 - val_loss: 0.6004 - learning_rate: 5.0000e-04
# Epoch 90/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7363 - loss: 0.6172 - val_accuracy: 0.7442 - val_loss: 0.5984 - learning_rate: 5.0000e-04
# Epoch 91/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7378 - loss: 0.6148 - val_accuracy: 0.7449 - val_loss: 0.5991 - learning_rate: 5.0000e-04
# Epoch 92/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7365 - loss: 0.6157 - val_accuracy: 0.7436 - val_loss: 0.6002 - learning_rate: 5.0000e-04
# Epoch 93/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.7353 - loss: 0.6165 - val_accuracy: 0.7433 - val_loss: 0.5981 - learning_rate: 5.0000e-04
# Epoch 94/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7375 - loss: 0.6157 - val_accuracy: 0.7419 - val_loss: 0.5989 - learning_rate: 5.0000e-04
# Epoch 95/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7365 - loss: 0.6167 - val_accuracy: 0.7432 - val_loss: 0.5983 - learning_rate: 5.0000e-04
# Epoch 96/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7372 - loss: 0.6150 - val_accuracy: 0.7454 - val_loss: 0.5982 - learning_rate: 5.0000e-04
# Epoch 97/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7368 - loss: 0.6159 - val_accuracy: 0.7431 - val_loss: 0.5983 - learning_rate: 5.0000e-04
# Epoch 98/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7369 - loss: 0.6146 - val_accuracy: 0.7436 - val_loss: 0.5985 - learning_rate: 5.0000e-04
# Epoch 99/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7374 - loss: 0.6152 - val_accuracy: 0.7429 - val_loss: 0.5977 - learning_rate: 5.0000e-04
# Epoch 100/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7383 - loss: 0.6154 - val_accuracy: 0.7437 - val_loss: 0.5980 - learning_rate: 5.0000e-04
# Epoch 101/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7373 - loss: 0.6152 - val_accuracy: 0.7420 - val_loss: 0.5980 - learning_rate: 5.0000e-04
# Epoch 102/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7370 - loss: 0.6152 - val_accuracy: 0.7420 - val_loss: 0.5981 - learning_rate: 5.0000e-04
# Epoch 103/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.7374 - loss: 0.6153 - val_accuracy: 0.7439 - val_loss: 0.5974 - learning_rate: 5.0000e-04
# Epoch 104/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7376 - loss: 0.6147 - val_accuracy: 0.7436 - val_loss: 0.5983 - learning_rate: 5.0000e-04
# Epoch 105/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7375 - loss: 0.6155 - val_accuracy: 0.7446 - val_loss: 0.5971 - learning_rate: 5.0000e-04
# Epoch 106/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.7377 - loss: 0.6144 - val_accuracy: 0.7446 - val_loss: 0.5978 - learning_rate: 5.0000e-04
# Epoch 107/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.7357 - loss: 0.6154 - val_accuracy: 0.7442 - val_loss: 0.5978 - learning_rate: 5.0000e-04
# Epoch 108/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.7381 - loss: 0.6140 - val_accuracy: 0.7432 - val_loss: 0.5981 - learning_rate: 5.0000e-04
# Epoch 109/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7380 - loss: 0.6140 - val_accuracy: 0.7447 - val_loss: 0.5968 - learning_rate: 5.0000e-04
# Epoch 110/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7379 - loss: 0.6145 - val_accuracy: 0.7445 - val_loss: 0.5965 - learning_rate: 5.0000e-04
# Epoch 111/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7384 - loss: 0.6129 - val_accuracy: 0.7441 - val_loss: 0.5967 - learning_rate: 5.0000e-04
# Epoch 112/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7385 - loss: 0.6137 - val_accuracy: 0.7445 - val_loss: 0.5967 - learning_rate: 5.0000e-04
# Epoch 113/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7381 - loss: 0.6139 - val_accuracy: 0.7442 - val_loss: 0.5976 - learning_rate: 5.0000e-04
# Epoch 114/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7381 - loss: 0.6125 - val_accuracy: 0.7446 - val_loss: 0.5964 - learning_rate: 5.0000e-04
# Epoch 115/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.7382 - loss: 0.6139 - val_accuracy: 0.7432 - val_loss: 0.5982 - learning_rate: 5.0000e-04
# Epoch 116/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7377 - loss: 0.6140 - val_accuracy: 0.7443 - val_loss: 0.5967 - learning_rate: 5.0000e-04
# Epoch 117/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7389 - loss: 0.6132 - val_accuracy: 0.7446 - val_loss: 0.5964 - learning_rate: 5.0000e-04
# Epoch 118/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7386 - loss: 0.6125 - val_accuracy: 0.7420 - val_loss: 0.5975 - learning_rate: 5.0000e-04
# Epoch 119/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7381 - loss: 0.6137 - val_accuracy: 0.7438 - val_loss: 0.5957 - learning_rate: 5.0000e-04
# Epoch 120/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7383 - loss: 0.6140 - val_accuracy: 0.7446 - val_loss: 0.5971 - learning_rate: 5.0000e-04
# Epoch 121/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7378 - loss: 0.6129 - val_accuracy: 0.7436 - val_loss: 0.5969 - learning_rate: 5.0000e-04
# Epoch 122/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7390 - loss: 0.6120 - val_accuracy: 0.7446 - val_loss: 0.5973 - learning_rate: 5.0000e-04
# Epoch 123/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.7394 - loss: 0.6123 - val_accuracy: 0.7456 - val_loss: 0.5959 - learning_rate: 5.0000e-04
# Epoch 124/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7382 - loss: 0.6134 - val_accuracy: 0.7436 - val_loss: 0.5971 - learning_rate: 5.0000e-04
# Epoch 125/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7381 - loss: 0.6134 - val_accuracy: 0.7441 - val_loss: 0.5972 - learning_rate: 5.0000e-04
# Epoch 126/150
# 1988/1993 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7378 - loss: 0.6117
# Epoch 126: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7379 - loss: 0.6139 - val_accuracy: 0.7442 - val_loss: 0.5960 - learning_rate: 5.0000e-04
# Epoch 127/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7391 - loss: 0.6120 - val_accuracy: 0.7452 - val_loss: 0.5948 - learning_rate: 2.5000e-04
# Epoch 128/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7394 - loss: 0.6095 - val_accuracy: 0.7442 - val_loss: 0.5951 - learning_rate: 2.5000e-04
# Epoch 129/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7378 - loss: 0.6101 - val_accuracy: 0.7452 - val_loss: 0.5949 - learning_rate: 2.5000e-04
# Epoch 130/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.7385 - loss: 0.6101 - val_accuracy: 0.7446 - val_loss: 0.5948 - learning_rate: 2.5000e-04
# Epoch 131/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7397 - loss: 0.6108 - val_accuracy: 0.7449 - val_loss: 0.5941 - learning_rate: 2.5000e-04
# Epoch 132/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.7394 - loss: 0.6103 - val_accuracy: 0.7449 - val_loss: 0.5942 - learning_rate: 2.5000e-04
# Epoch 133/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - accuracy: 0.7382 - loss: 0.6122 - val_accuracy: 0.7438 - val_loss: 0.5947 - learning_rate: 2.5000e-04
# Epoch 134/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.7402 - loss: 0.6099 - val_accuracy: 0.7460 - val_loss: 0.5937 - learning_rate: 2.5000e-04
# Epoch 135/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 22s 8ms/step - accuracy: 0.7379 - loss: 0.6115 - val_accuracy: 0.7459 - val_loss: 0.5949 - learning_rate: 2.5000e-04
# Epoch 136/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.7397 - loss: 0.6100 - val_accuracy: 0.7452 - val_loss: 0.5946 - learning_rate: 2.5000e-04
# Epoch 137/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 20s 7ms/step - accuracy: 0.7391 - loss: 0.6090 - val_accuracy: 0.7438 - val_loss: 0.5951 - learning_rate: 2.5000e-04
# Epoch 138/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 15s 8ms/step - accuracy: 0.7403 - loss: 0.6102 - val_accuracy: 0.7447 - val_loss: 0.5944 - learning_rate: 2.5000e-04
# Epoch 139/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - accuracy: 0.7395 - loss: 0.6092 - val_accuracy: 0.7463 - val_loss: 0.5946 - learning_rate: 2.5000e-04
# Epoch 140/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 15s 8ms/step - accuracy: 0.7403 - loss: 0.6093 - val_accuracy: 0.7471 - val_loss: 0.5941 - learning_rate: 2.5000e-04
# Epoch 141/150
# 1990/1993 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7342 - loss: 0.6187
# Epoch 141: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 15s 8ms/step - accuracy: 0.7387 - loss: 0.6101 - val_accuracy: 0.7452 - val_loss: 0.5939 - learning_rate: 2.5000e-04
# Epoch 142/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - accuracy: 0.7379 - loss: 0.6102 - val_accuracy: 0.7445 - val_loss: 0.5940 - learning_rate: 1.2500e-04
# Epoch 143/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.7395 - loss: 0.6087 - val_accuracy: 0.7447 - val_loss: 0.5938 - learning_rate: 1.2500e-04
# Epoch 144/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - accuracy: 0.7398 - loss: 0.6086 - val_accuracy: 0.7447 - val_loss: 0.5937 - learning_rate: 1.2500e-04
# Epoch 145/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.7406 - loss: 0.6089 - val_accuracy: 0.7454 - val_loss: 0.5938 - learning_rate: 1.2500e-04
# Epoch 146/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - accuracy: 0.7400 - loss: 0.6080 - val_accuracy: 0.7459 - val_loss: 0.5937 - learning_rate: 1.2500e-04
# Epoch 147/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - accuracy: 0.7393 - loss: 0.6078 - val_accuracy: 0.7466 - val_loss: 0.5936 - learning_rate: 1.2500e-04
# Epoch 148/150
# 1988/1993 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7383 - loss: 0.6096
# Epoch 148: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - accuracy: 0.7392 - loss: 0.6084 - val_accuracy: 0.7464 - val_loss: 0.5939 - learning_rate: 1.2500e-04
# Epoch 149/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - accuracy: 0.7414 - loss: 0.6090 - val_accuracy: 0.7467 - val_loss: 0.5936 - learning_rate: 6.2500e-05
# Epoch 150/150
# 1993/1993 ━━━━━━━━━━━━━━━━━━━━ 25s 12ms/step - accuracy: 0.7405 - loss: 0.6077 - val_accuracy: 0.7463 - val_loss: 0.5935 - learning_rate: 6.2500e-05
# Restoring model weights from the end of the best epoch: 150.
# ✅ Entrenamiento completado - 150 épocas

# %%
# Evaluar modelo sintético
y_pred_syn = modelo_sintetico.predict(X_test_syn_scaled)  # ← Usar modelo_sintetico, NO synthesizer
y_pred_syn_classes = np.argmax(y_pred_syn, axis=1)

accuracy_syn = accuracy_score(y_test_syn, y_pred_syn_classes)
precision_syn = precision_score(y_test_syn, y_pred_syn_classes, average='weighted')
recall_syn = recall_score(y_test_syn, y_pred_syn_classes, average='weighted')
f1_syn = f1_score(y_test_syn, y_pred_syn_classes, average='weighted')

print('='*60)
print('MODELO SINTÉTICO - RESULTADOS')
print('='*60)
print(f'Accuracy:  {accuracy_syn:.4f}')
print(f'Precision: {precision_syn:.4f}')
print(f'Recall:    {recall_syn:.4f}')
print(f'F1-Score:  {f1_syn:.4f}')

print('\nReporte de Clasificación:')
print(classification_report(y_test_syn, y_pred_syn_classes, target_names=le_target.classes_))

# Matriz de confusión
cm_syn = confusion_matrix(y_test_syn, y_pred_syn_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm_syn, annot=True, fmt='d', cmap='Purples', 
            xticklabels=le_target.classes_, yticklabels=le_target.classes_)
plt.title('Matriz de Confusión - Modelo Sintético')
plt.ylabel('Clase Real')
plt.xlabel('Clase Predicha')
plt.tight_layout()
plt.show()
# Out:
# 623/623 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# ============================================================
# MODELO SINTÉTICO - RESULTADOS
# ============================================================
# Accuracy:  0.7492
# Precision: 0.7448
# Recall:    0.7492
# F1-Score:  0.7324
#
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#         Alto       0.75      0.80      0.77      7128
#         Bajo       0.76      0.86      0.81      9581
#        Medio       0.71      0.31      0.43      3212
#
#     accuracy                           0.75     19921
#    macro avg       0.74      0.66      0.67     19921
# weighted avg       0.74      0.75      0.73     19921

# %%
# Comparar distribuciones real vs sintético
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# RMU_PUESTO
axes[0, 0].hist(df_original_limpio['RMU_PUESTO'], bins=50, alpha=0.7, label='Real', color='blue')
axes[0, 0].hist(df_sintetico['RMU_PUESTO'], bins=50, alpha=0.7, label='Sintético', color='purple')
axes[0, 0].set_title('Distribución RMU_PUESTO')
axes[0, 0].legend()
axes[0, 0].set_xlabel('Sueldo')

# CATEGORIA_SUELDO
real_counts = df_original_limpio['CATEGORIA_SUELDO'].value_counts().sort_index()
syn_counts = df_sintetico['CATEGORIA_SUELDO'].value_counts().sort_index()
x = np.arange(len(real_counts))
axes[0, 1].bar(x - 0.2, real_counts.values, 0.4, label='Real', color='blue', alpha=0.7)
axes[0, 1].bar(x + 0.2, syn_counts.values, 0.4, label='Sintético', color='purple', alpha=0.7)
axes[0, 1].set_title('Distribución CATEGORIA_SUELDO')
axes[0, 1].set_xticks(x)
axes[0, 1].set_xticklabels(real_counts.index)
axes[0, 1].legend()

# EDAD
if 'EDAD' in df_original_limpio.columns and 'EDAD' in df_sintetico.columns:
    axes[1, 0].hist(df_original_limpio['EDAD'], bins=30, alpha=0.7, label='Real', color='blue')
    axes[1, 0].hist(df_sintetico['EDAD'], bins=30, alpha=0.7, label='Sintético', color='purple')
    axes[1, 0].set_title('Distribución EDAD')
    axes[1, 0].legend()

# ANTIGUEDAD_DIAS
if 'ANTIGUEDAD_DIAS' in df_original_limpio.columns and 'ANTIGUEDAD_DIAS' in df_sintetico.columns:
    axes[1, 1].hist(df_original_limpio['ANTIGUEDAD_DIAS'], bins=30, alpha=0.7, label='Real', color='blue')
    axes[1, 1].hist(df_sintetico['ANTIGUEDAD_DIAS'], bins=30, alpha=0.7, label='Sintético', color='purple')
    axes[1, 1].set_title('Distribución ANTIGUEDAD_DIAS')
    axes[1, 1].legend()

plt.tight_layout()
plt.show()

print('Estadísticas comparativas:')
print(f'\nRMU_PUESTO:')
print(f'  Real:      Media=${df_original_limpio["RMU_PUESTO"].mean():.2f}, Std=${df_original_limpio["RMU_PUESTO"].std():.2f}')
print(f'  Sintético: Media=${df_sintetico["RMU_PUESTO"].mean():.2f}, Std=${df_sintetico["RMU_PUESTO"].std():.2f}')
# Out:
# Estadísticas comparativas:
#
# RMU_PUESTO:
#   Real:      Media=$967.92, Std=$524.24
#   Sintético: Media=$1030.63, Std=$662.45

# %%
# Comparación completa
print('='*80)
print('COMPARACIÓN FINAL: ORIGINAL vs ANONIMIZADO vs SINTÉTICO')
print('='*80)
print(f'{"Métrica":<15} {"Original":<15} {"Anonimizado":<15} {"Sintético":<15}')
print('-'*80)
print(f'{"Accuracy":<15} {accuracy_orig:<15.4f} {accuracy_anon:<15.4f} {accuracy_syn:<15.4f}')
print(f'{"Precision":<15} {precision_orig:<15.4f} {precision_anon:<15.4f} {precision_syn:<15.4f}')
print(f'{"Recall":<15} {recall_orig:<15.4f} {recall_anon:<15.4f} {recall_syn:<15.4f}')
print(f'{"F1-Score":<15} {f1_orig:<15.4f} {f1_anon:<15.4f} {f1_syn:<15.4f}')
print('='*80)

# Visualización de las 3 matrices
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[0],
            xticklabels=le_target.classes_, yticklabels=le_target.classes_)
axes[0].set_title(f'Original\nAccuracy: {accuracy_orig:.2%}')
axes[0].set_ylabel('Clase Real')
axes[0].set_xlabel('Clase Predicha')

sns.heatmap(cm_anon, annot=True, fmt='d', cmap='Greens', ax=axes[1],
            xticklabels=le_target.classes_, yticklabels=le_target.classes_)
axes[1].set_title(f'Anonimizado\nAccuracy: {accuracy_anon:.2%}')
axes[1].set_ylabel('Clase Real')
axes[1].set_xlabel('Clase Predicha')

sns.heatmap(cm_syn, annot=True, fmt='d', cmap='Purples', ax=axes[2],
            xticklabels=le_target.classes_, yticklabels=le_target.classes_)
axes[2].set_title(f'Sintético\nAccuracy: {accuracy_syn:.2%}')
axes[2].set_ylabel('Clase Real')
axes[2].set_xlabel('Clase Predicha')

plt.tight_layout()
plt.show()

# Gráfico de barras
metricas = ['Accuracy', 'Precision', 'Recall', 'F1-Score']
original_vals = [accuracy_orig, precision_orig, recall_orig, f1_orig]
anon_vals = [accuracy_anon, precision_anon, recall_anon, f1_anon]
syn_vals = [accuracy_syn, precision_syn, recall_syn, f1_syn]

x = np.arange(len(metricas))
width = 0.25

fig, ax = plt.subplots(figsize=(12, 6))
ax.bar(x - width, original_vals, width, label='Original', color='blue', alpha=0.8)
ax.bar(x, anon_vals, width, label='Anonimizado', color='green', alpha=0.8)
ax.bar(x + width, syn_vals, width, label='Sintético', color='purple', alpha=0.8)

ax.set_ylabel('Score')
ax.set_title('Comparación: Original vs Anonimizado vs Sintético')
ax.set_xticks(x)
ax.set_xticklabels(metricas)
ax.legend()
ax.set_ylim([0, 1])
ax.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# ================================================================================
# COMPARACIÓN FINAL: ORIGINAL vs ANONIMIZADO vs SINTÉTICO
# ================================================================================
# Métrica         Original        Anonimizado     Sintético
# --------------------------------------------------------------------------------
# Accuracy        0.8399          0.7392          0.7492
# Precision       0.8538          0.6451          0.7448
# Recall          0.8399          0.7392          0.7492
# F1-Score        0.8441          0.6779          0.7324
# ================================================================================

# %%
# Trade-off Privacidad-Utilidad
print('='*80)
print('ANÁLISIS TRADE-OFF PRIVACIDAD vs UTILIDAD')
print('='*80)

perdida_anon = accuracy_orig - accuracy_anon
perdida_syn = accuracy_orig - accuracy_syn

print(f'\nPérdida de Accuracy respecto al Original:')
print(f'  Anonimizado: {perdida_anon:.4f} ({(perdida_anon/accuracy_orig)*100:.2f}%)')
print(f'  Sintético:   {perdida_syn:.4f} ({(perdida_syn/accuracy_orig)*100:.2f}%)')

print(f'\nNivel de Privacidad:')
print(f'  Original:     ⭐ (bajo)')
print(f'  Anonimizado:  ⭐⭐⭐ (medio-alto)')
print(f'  Sintético:    ⭐⭐⭐⭐⭐ (muy alto)')

print(f'\nConclusiones:')
if perdida_syn < 0.05:
    print(f'  ✅ Datos sintéticos EXCELENTES (<5% pérdida)')
elif perdida_syn < 0.10:
    print(f'  ✅ Datos sintéticos BUENOS (<10% pérdida)')
else:
    print(f'  ⚠️ Datos sintéticos: Pérdida significativa (>10%)')

if accuracy_syn > accuracy_anon:
    print(f'\n🎯 SINTÉTICOS SUPERIORES: +{(accuracy_syn-accuracy_anon):.4f} vs anonimización')
else:
    print(f'\n⚠️ Anonimización mejor: +{(accuracy_anon-accuracy_syn):.4f} vs sintéticos')

# Guardar todo
modelo_sintetico.save('modelo_sintetico.keras')

resultados_final = {
    'original': {'accuracy': float(accuracy_orig), 'precision': float(precision_orig), 
                 'recall': float(recall_orig), 'f1': float(f1_orig), 'privacidad': 'baja'},
    'anonimizado': {'accuracy': float(accuracy_anon), 'precision': float(precision_anon), 
                    'recall': float(recall_anon), 'f1': float(f1_anon), 'privacidad': 'media-alta'},
    'sintetico': {'accuracy': float(accuracy_syn), 'precision': float(precision_syn), 
                  'recall': float(recall_syn), 'f1': float(f1_syn), 'privacidad': 'muy alta'}
}

with open('resultados_final.json', 'w') as f:
    json.dump(resultados_final, f, indent=4)

print('\n✅ Modelos y resultados guardados')
# Out:
# ================================================================================
# ANÁLISIS TRADE-OFF PRIVACIDAD vs UTILIDAD
# ================================================================================
#
# Pérdida de Accuracy respecto al Original:
#   Anonimizado: 0.1007 (11.99%)
#   Sintético:   0.0907 (10.79%)
#
# Nivel de Privacidad:
#   Original:     ⭐ (bajo)
#   Anonimizado:  ⭐⭐⭐ (medio-alto)
#   Sintético:    ⭐⭐⭐⭐⭐ (muy alto)
#
# Conclusiones:
#   ✅ Datos sintéticos BUENOS (<10% pérdida)
#
# 🎯 SINTÉTICOS SUPERIORES: +0.0100 vs anonimización
#
# ✅ Modelos y resultados guardados
